# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#Original Draft Data

master_data = pd.read_csv("../starting file/Draft_SD_CSV.csv")
# Out:
# C:\Users\daily\Anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#Creating WAR Group Column

master_data.loc[(master_data["Total_WAR"] < 5), "WAR Group"] = "Less than 5 WAR"
master_data.loc[(master_data["Total_WAR"] < 10) & (master_data["Total_WAR"] >= 5), "WAR Group"] = "5-10 WAR"
master_data.loc[(master_data["Total_WAR"] < 15) & (master_data["Total_WAR"] >= 10), "WAR Group"] = "10-15 WAR"
master_data.loc[(master_data["Total_WAR"] < 20) & (master_data["Total_WAR"] >= 15), "WAR Group"] = "15-20 WAR"
master_data.loc[(master_data["Total_WAR"] < 25) & (master_data["Total_WAR"] >= 20), "WAR Group"] = "20-25 WAR"
master_data.loc[(master_data["Total_WAR"] >= 25), "WAR Group"] = "More than 25 WAR"
master_data["WAR Group"].fillna("No Major League Experience", inplace = True)

# %%
#Limiting the data to only Diamondbacks players

diamondbacks_data = master_data.loc[master_data["Franchise"] == "Diamondbacks"]

#Only showing players that signed with the Diamondbacks

signed_diamondbacks_data = diamondbacks_data.loc[diamondbacks_data["Signed"] == "Y"]

#Grouped by draft class

draft_class_year = signed_diamondbacks_data.groupby("Year")

#Unsigned Diamondbacks draft picks

unsigned_diamondbacks_data = diamondbacks_data.loc[diamondbacks_data["Signed"] == "N"]

# %%
#Total WAR by draft class sorted by best to worst

draft_class_year["Total_WAR"].sum().sort_values(ascending = False)
# Out:
# Year
# 2009    54.6
# 2006    35.9
# 2001    34.3
# 2005    27.1
# 1996    26.9
# 2000    25.4
# 2011    23.2
# 2004    23.0
# 2008    17.5
# 2010    15.7
# 1999    14.6
# 2003    12.0
# 2007    10.0
# 2002     7.7
# 2012     6.5
# 2015     3.6
# 2013     3.3
# 1998     1.8
# 2016     1.5
# 1997     0.3
# 2018     0.0
# 2017     0.0
# 2019     0.0
# 2014    -1.5
# Name: Total_WAR, dtype: float64

# %%
#WAR by draft class year bargraph

draft_class_year["Total_WAR"].sum().plot(kind = "bar", color = ["#A71930", "#E3D4AD"], width = .8, fontsize = 12, edgecolor = "#A71930", figsize = (16, 10.5))
plt.title("Arizona Diamondbacks\n Total Draft Class WAR ", size = 28)
plt.xlabel("Draft Year", size = 16)
plt.ylabel("WAR", size = 16)
plt.yticks(np.arange(-10, 101, step = 5))
plt.grid(color = "whitesmoke", linestyle = "-", axis = "y")
plt.savefig("Diamondbacks WAR Total by Draft Year.png")
plt.show()

# %%
#Best draft picks in franchise history

signed_diamondbacks_data.sort_values(["Total_WAR"],ascending = False).head(10)
# Out:
#        Year  Rnd  OvPck            Tm     Franchise Signed              Name  \
# 51899  2009    8    246  Diamondbacks  Diamondbacks      Y  Paul Goldschmidt
# 38545  2000    8    249  Diamondbacks  Diamondbacks      Y      Brandon Webb
# 47205  2006    1     11  Diamondbacks  Diamondbacks      Y      Max Scherzer
# 40086  2001   11    338  Diamondbacks  Diamondbacks      Y         Dan Uggla
# 45694  2005    1      1  Diamondbacks  Diamondbacks      Y      Justin Upton
# 32187  1996    5    155       D'backs  Diamondbacks      Y        Brad Penny
# 51670  2009    1     17  Diamondbacks  Diamondbacks      Y      A.J. Pollock
# 53746  2010   19    571  Diamondbacks  Diamondbacks      Y        Adam Eaton
# 54702  2011    1      3  Diamondbacks  Diamondbacks      Y      Trevor Bauer
# 50192  2008    1     43  Diamondbacks  Diamondbacks      Y        Wade Miley
#
#        Debut_Year   playerID    fg_id  Hitting_WAR  Pitching_WAR  Total_WAR  \
# 51899      2011.0  goldspa01   9218.0         31.1           0.0       31.1
# 38545      2003.0   webbbr01   1692.0         -1.9          29.6       27.7
# 47205      2008.0  scherma01   3137.0          0.1          26.1       26.2
# 40086      2006.0  ugglada01   3442.0         23.5           0.0       23.5
# 45694      2007.0  uptonju01   5222.0         19.7           0.0       19.7
# 32187      2000.0  pennybr01    535.0         -0.4          20.0       19.6
# 51670      2012.0  polloaj01   9256.0         17.2           0.0       17.2
# 53746      2012.0  eatonad02  11205.0         17.0           0.0       17.0
# 54702      2012.0  bauertr01  12703.0         -0.2          14.1       13.9
# 50192      2011.0  mileywa01   8779.0          0.2          12.1       12.3
#
#        Pos Type                                School          City State  \
# 51899   1B  4Yr                Texas State University    San Marcos    TX
# 38545  RHP  4Yr                University of Kentucky     Lexington    KY
# 47205  RHP  4Yr                University of Missouri      Columbia    MO
# 40086   2B  4Yr                 University of Memphis       Memphis    TN
# 45694   SS   HS                       Great Bridge HS    Chesapeake    VA
# 32187  RHP   HS                       Broken Arrow HS  Broken Arrow    OK
# 51670   CF  4Yr              University of Notre Dame    South Bend    IN
# 53746   OF  4Yr              Miami University of Ohio        Oxford    OH
# 54702  RHP  4Yr  University of California Los Angeles   Los Angeles    CA
# 50192  LHP  4Yr     Southeastern Louisiana University       Hammond    LA
#
#               WAR Group
# 51899  More than 25 WAR
# 38545  More than 25 WAR
# 47205  More than 25 WAR
# 40086         20-25 WAR
# 45694         15-20 WAR
# 32187         15-20 WAR
# 51670         15-20 WAR
# 53746         15-20 WAR
# 54702         10-15 WAR
# 50192         10-15 WAR

# %%
#Biggest draft busts found by looking at first rounders who had less than 5 WAR or didn't make majors

signed_diamondbacks_data.loc[((signed_diamondbacks_data["WAR Group"] == "Less than 5 WAR") |
(signed_diamondbacks_data["WAR Group"] == "No Major League Experience")) & 
(signed_diamondbacks_data["Rnd"] == 1)]
# Out:
#        Year  Rnd  OvPck            Tm     Franchise Signed              Name  \
# 32062  1996    1     30       D'backs  Diamondbacks      Y    Nick Bierbrodt
# 33800  1997    1     30       D'backs  Diamondbacks      Y         Jack Cust
# 36826  1999    1      4  Diamondbacks  Diamondbacks      Y       Corey Myers
# 36853  1999    1     31  Diamondbacks  Diamondbacks      Y      Casey Daigle
# 39770  2001    1     22  Diamondbacks  Diamondbacks      Y      Jason Bulger
# 41260  2002    1     27  Diamondbacks  Diamondbacks      Y     Sergio Santos
# 42734  2003    1     19  Diamondbacks  Diamondbacks      Y     Conor Jackson
# 45724  2005    1     31  Diamondbacks  Diamondbacks      Y        Matt Torra
# 47228  2006    1     34  Diamondbacks  Diamondbacks      Y      Brooks Brown
# 48746  2007    1     50  Diamondbacks  Diamondbacks      Y        Wes Roemer
# 48757  2007    1     61  Diamondbacks  Diamondbacks      Y         Ed Easley
# 50175  2008    1     26  Diamondbacks  Diamondbacks      Y  Daniel Schlereth
# 51669  2009    1     16  Diamondbacks  Diamondbacks      Y  Bobby Borchering
# 51688  2009    1     35  Diamondbacks  Diamondbacks      Y     Matt Davidson
# 51694  2009    1     41  Diamondbacks  Diamondbacks      Y      Chris Owings
# 51698  2009    1     45  Diamondbacks  Diamondbacks      Y     Mike Belfiore
# 54742  2011    1     43  Diamondbacks  Diamondbacks      Y     Andrew Chafin
# 56255  2012    1     26  Diamondbacks  Diamondbacks      Y    Stryker Trahan
# 57482  2013    1     15  Diamondbacks  Diamondbacks      Y    Braden Shipley
# 57503  2013    1     36  Diamondbacks  Diamondbacks      Y       Aaron Blair
# 58699  2014    1     16  Diamondbacks  Diamondbacks      Y   Touki Toussaint
# 59899  2015    1      1  Diamondbacks  Diamondbacks      Y    Dansby Swanson
# 61152  2016    1     39  Diamondbacks  Diamondbacks      Y    Anfernee Grier
# 62336  2017    1      7  Diamondbacks  Diamondbacks      Y       Pavin Smith
# 63583  2018    1     39  Diamondbacks  Diamondbacks      Y     Jake McCarthy
# 64774  2019    1     16  Diamondbacks  Diamondbacks      Y    Corbin Carroll
# 64784  2019    1     26  Diamondbacks  Diamondbacks      Y     Blake Walston
# 64791  2019    1     33  Diamondbacks  Diamondbacks      Y    Brennan Malone
# 64792  2019    1     34  Diamondbacks  Diamondbacks      Y      Drey Jameson
#
#        Debut_Year   playerID    fg_id  Hitting_WAR  Pitching_WAR  Total_WAR  \
# 32062      2001.0  bierbni01   1194.0          0.4          -1.0       -0.6
# 33800      2001.0   custja01   1564.0          2.4           0.0        2.4
# 36826         NaN        NaN      NaN          NaN           NaN        NaN
# 36853      2004.0  daiglca01   1880.0         -0.1          -0.6       -0.7
# 39770      2005.0  bulgeja01   3915.0          0.0           0.1        0.1
# 41260      2010.0  santose01   4734.0          0.0           2.3        2.3
# 42734      2005.0  jacksco01   5997.0          2.8           0.0        2.8
# 45724         NaN        NaN      NaN          NaN           NaN        NaN
# 47228      2014.0  brownbr02   5679.0          0.0           0.2        0.2
# 48746         NaN        NaN      NaN          NaN           NaN        NaN
# 48757      2015.0  easleed01   2487.0         -0.2           0.0       -0.2
# 50175      2009.0  schleda01   8739.0          0.0          -0.7       -0.7
# 51669         NaN        NaN      NaN          NaN           NaN        NaN
# 51688      2013.0  davidma02   7226.0          0.3           0.0        0.3
# 51694      2013.0  owingch01  10030.0          0.4          -0.1        0.3
# 51698      2013.0  belfimi01   9324.0          0.0          -0.1       -0.1
# 54742      2014.0  chafian01  12988.0          0.0           4.0        4.0
# 56255         NaN        NaN      NaN          NaN           NaN        NaN
# 57482      2016.0  shiplbr01  15158.0         -0.2          -0.6       -0.8
# 57503      2016.0  blairaa01  14934.0         -0.1          -0.7       -0.8
# 58699      2018.0  toussto01  16929.0         -0.2           0.3        0.1
# 59899      2016.0  swansda01  18314.0          3.9           0.0        3.9
# 61152         NaN        NaN      NaN          NaN           NaN        NaN
# 62336         NaN        NaN      NaN          NaN           NaN        NaN
# 63583         NaN        NaN      NaN          NaN           NaN        NaN
# 64774         NaN        NaN      NaN          NaN           NaN        NaN
# 64784         NaN        NaN      NaN          NaN           NaN        NaN
# 64791         NaN        NaN      NaN          NaN           NaN        NaN
# 64792         NaN        NaN      NaN          NaN           NaN        NaN
#
#        Pos Type                                 School             City State  \
# 32062  LHP   HS                            Millikan HS       Long Beach    CA
# 33800   1B   HS                          Immaculata HS       Somerville    NJ
# 36826   SS   HS                        Desert Vista HS          Phoenix    AZ
# 36853  RHP   HS                             Sulphur HS          Sulphur    LA
# 39770  RHP  4Yr              Valdosta State University         Valdosta    GA
# 41260   SS   HS                           Mater Dei HS        Santa Ana    CA
# 42734   1B  4Yr      University of California Berkeley         Berkeley    CA
# 45724  RHP  4Yr    University of Massachusetts Amherst          Amherst    MA
# 47228  RHP  4Yr                  University of Georgia           Athens    GA
# 48746  RHP  4Yr  California State University Fullerton        Fullerton    CA
# 48757    C  4Yr           Mississippi State University       Starkville    MS
# 50175  LHP  4Yr                  University of Arizona           Tucson    AZ
# 51669   3B   HS                        Bishop Verot HS       Fort Myers    FL
# 51688   3B   HS                             Yucaipa HS          Yucaipa    CA
# 51694   SS   HS                             Gilbert HS          Gilbert    SC
# 51698  LHP  4Yr                         Boston College    Chestnut Hill    MA
# 54742  LHP  4Yr                  Kent State University             Kent    OH
# 56255    C   HS                            Acadiana HS        Lafayette    LA
# 57482  RHP  4Yr              University of Nevada Reno             Reno    NV
# 57503  RHP  4Yr                    Marshall University       Huntington    WV
# 58699  RHP   HS        Coral Springs Christian Academy    Coral Springs    FL
# 59899   SS  4Yr                  Vanderbilt University        Nashville    TN
# 61152   OF  4Yr                      Auburn University           Auburn    AL
# 62336   1B  4Yr                 University of Virginia  Charlottesville    VA
# 63583   OF  4Yr                 University of Virginia  Charlottesville    VA
# 64774   CF   HS                        Lakeside School          Seattle    WA
# 64784    P   HS                         New Hanover HS       Wilmington    NC
# 64791    P   HS                            IMG Academy        Bradenton    FL
# 64792    P  4Yr                  Ball State University           Muncie    IN
#
#                         WAR Group
# 32062             Less than 5 WAR
# 33800             Less than 5 WAR
# 36826  No Major League Experience
# 36853             Less than 5 WAR
# 39770             Less than 5 WAR
# 41260             Less than 5 WAR
# 42734             Less than 5 WAR
# 45724  No Major League Experience
# 47228             Less than 5 WAR
# 48746  No Major League Experience
# 48757             Less than 5 WAR
# 50175             Less than 5 WAR
# 51669  No Major League Experience
# 51688             Less than 5 WAR
# 51694             Less than 5 WAR
# 51698             Less than 5 WAR
# 54742             Less than 5 WAR
# 56255  No Major League Experience
# 57482             Less than 5 WAR
# 57503             Less than 5 WAR
# 58699             Less than 5 WAR
# 59899             Less than 5 WAR
# 61152  No Major League Experience
# 62336  No Major League Experience
# 63583  No Major League Experience
# 64774  No Major League Experience
# 64784  No Major League Experience
# 64791  No Major League Experience
# 64792  No Major League Experience

# %%
#Best unsigned draft picks in franchise history

unsigned_diamondbacks_data.sort_values(["Total_WAR"],ascending = False).head(10)
# Out:
#        Year  Rnd  OvPck            Tm     Franchise Signed               Name  \
# 39175  2000   29    879  Diamondbacks  Diamondbacks      N        Ian Kinsler
# 40536  2001   26    788  Diamondbacks  Diamondbacks      N        Ian Kinsler
# 33561  1996   54   1531       D'backs  Diamondbacks      N     Jason Jennings
# 41178  2001   48   1430  Diamondbacks  Diamondbacks      N         Seth Smith
# 43261  2003   18    546  Diamondbacks  Diamondbacks      N      Chris Coghlan
# 32247  1996    7    215       D'backs  Diamondbacks      N       Casey Fossum
# 33638  1996   61   1608       D'backs  Diamondbacks      N  Brandon Duckworth
# 45211  2004   34   1016  Diamondbacks  Diamondbacks      N    David Hernandez
# 51098  2008   31    948  Diamondbacks  Diamondbacks      N        Taylor Cole
# 49249  2007   18    553  Diamondbacks  Diamondbacks      N        Sammy Solis
#
#        Debut_Year   playerID    fg_id  Hitting_WAR  Pitching_WAR  Total_WAR  \
# 39175      2006.0  kinslia01   6195.0         26.6           0.0       26.6
# 40536      2006.0  kinslia01   6195.0         26.6           0.0       26.6
# 33561      2001.0  jennija01    434.0          1.5          12.7       14.2
# 41178      2007.0  smithse01   7331.0          7.7           0.0        7.7
# 43261      2009.0  coghlch01   6878.0          7.2           0.0        7.2
# 32247      2001.0  fossuca01    188.0         -0.3           4.9        4.6
# 33638      2001.0  duckwbr01    954.0          0.9           3.2        4.1
# 45211      2009.0  hernada01   4259.0          0.0           2.9        2.9
# 51098      2017.0   coleta01  11964.0          0.0           1.3        1.3
# 49249      2015.0  solissa01  11457.0          0.0           0.8        0.8
#
#        Pos Type                      School            City State  \
# 39175   SS   HS           Canyon del Oro HS      Oro Valley    AZ
# 40536   SS   JC     Central Arizona College        Coolidge    AZ
# 33561  RHP   HS          Ralph H. Poteet HS        Mesquite    TX
# 41178   OF   HS      Hillcrest Christian HS         Jackson    MS
# 43261    C   HS                East Lake HS  Tarpon Springs    FL
# 32247  LHP   HS                   Midway HS            Waco    TX
# 33638  RHP   JC   College of Southern Idaho      Twin Falls    ID
# 45211  RHP   JC      Cosumnes River College      Sacramento    CA
# 51098  RHP   JC  College of Southern Nevada       Henderson    NV
# 49249  LHP   HS                Agua Fria HS        Avondale    AZ
#
#               WAR Group
# 39175  More than 25 WAR
# 40536  More than 25 WAR
# 33561         10-15 WAR
# 41178          5-10 WAR
# 43261          5-10 WAR
# 32247   Less than 5 WAR
# 33638   Less than 5 WAR
# 45211   Less than 5 WAR
# 51098   Less than 5 WAR
# 49249   Less than 5 WAR

# %%
#Best Draft Picks outside the top 10 rounds

hidden_gems = signed_diamondbacks_data.loc[signed_diamondbacks_data["Rnd"] > 10].sort_values("Total_WAR", ascending = False)

hidden_gems.head(10)
# Out:
#        Year  Rnd  OvPck            Tm     Franchise Signed             Name  \
# 40086  2001   11    338  Diamondbacks  Diamondbacks      Y        Dan Uggla
# 53746  2010   19    571  Diamondbacks  Diamondbacks      Y       Adam Eaton
# 44671  2004   16    476  Diamondbacks  Diamondbacks      Y    Mark Reynolds
# 33117  1996   36   1085       D'backs  Diamondbacks      Y    Junior Spivey
# 37360  1999   18    538  Diamondbacks  Diamondbacks      Y     Lyle Overbay
# 49159  2007   15    463  Diamondbacks  Diamondbacks      Y  Josh Collmenter
# 50978  2008   27    828  Diamondbacks  Diamondbacks      Y        Ryan Cook
# 36260  1998   29    883  Diamondbacks  Diamondbacks      Y     Mike Koplove
# 49489  2007   26    793  Diamondbacks  Diamondbacks      Y      Tommy Layne
# 41692  2002   15    459  Diamondbacks  Diamondbacks      Y   Dustin Nippert
#
#        Debut_Year   playerID    fg_id  Hitting_WAR  Pitching_WAR  Total_WAR  \
# 40086      2006.0  ugglada01   3442.0         23.5           0.0       23.5
# 53746      2012.0  eatonad02  11205.0         17.0           0.0       17.0
# 44671      2007.0  reynoma01   7619.0          9.4           0.0        9.4
# 33117      2001.0  spiveju01     74.0          7.5           0.0        7.5
# 37360      2001.0  overbly01   1617.0          6.9           0.0        6.9
# 49159      2011.0  collmjo01   7312.0         -0.1           5.1        5.0
# 50978      2011.0   cookry01   8855.0          0.0           3.0        3.0
# 36260      2001.0  koplomi01     63.0         -0.1           1.8        1.7
# 49489      2012.0  layneto01   7501.0          0.0           1.0        1.0
# 41692      2005.0  nippedu01   4426.0          0.0           0.9        0.9
#
#        Pos Type                             School             City State  \
# 40086   2B  4Yr              University of Memphis          Memphis    TN
# 53746   OF  4Yr           Miami University of Ohio           Oxford    OH
# 44671   SS  4Yr             University of Virginia  Charlottesville    VA
# 33117   2B   JC    Cowley County Community College    Arkansas City    KS
# 37360   1B  4Yr          University of Nevada Reno             Reno    NV
# 49159  RHP  4Yr        Central Michigan University   Mount Pleasant    MI
# 50978  RHP  4Yr  University of Southern California      Los Angeles    CA
# 36260  RHP  4Yr             University of Delaware           Newark    DE
# 49489  LHP  NaN                                NaN              NaN   NaN
# 41692  RHP  4Yr           West Virginia University       Morgantown    WV
#
#              WAR Group
# 40086        20-25 WAR
# 53746        15-20 WAR
# 44671         5-10 WAR
# 33117         5-10 WAR
# 37360         5-10 WAR
# 49159         5-10 WAR
# 50978  Less than 5 WAR
# 36260  Less than 5 WAR
# 49489  Less than 5 WAR
# 41692  Less than 5 WAR

# %%
#Creating table for percentage of picks by school type

draft_year_school_table_pct = pd.crosstab(diamondbacks_data["Year"], diamondbacks_data["Type"], normalize = "index")

100 * round(draft_year_school_table_pct,3)
# Out:
# Type   4Yr    HS    JC
# Year
# 1996  38.7  48.4  12.9
# 1997  30.0  56.7  13.3
# 1998  27.1  52.1  20.8
# 1999  47.9  37.5  14.6
# 2000  51.0  30.6  18.4
# 2001  42.0  32.0  26.0
# 2002  52.0  28.0  20.0
# 2003  66.7  19.6  13.7
# 2004  61.2  16.3  22.4
# 2005  50.0  16.0  34.0
# 2006  60.0  22.0  18.0
# 2007  70.6  23.5   5.9
# 2008  50.0  23.1  26.9
# 2009  51.9  33.3  14.8
# 2010  59.2  22.4  18.4
# 2011  64.7  27.5   7.8
# 2012  62.5  35.0   2.5
# 2013  68.3  26.8   4.9
# 2014  50.0  35.7  14.3
# 2015  77.5  10.0  12.5
# 2016  65.0  20.0  15.0
# 2017  65.9  24.4   9.8
# 2018  78.0  19.5   2.4
# 2019  51.1  42.2   6.7

# %%
#Bar chart of table above

colors = ["#A71930", "#E3D4AD", "#000000"]

(100 * round(draft_year_school_table_pct,3)).plot(kind = "bar", color = colors, width = .7, fontsize = 12, 
edgecolor = "#A71930", stacked = True, figsize = (16, 10.5))
plt.title("Diamondbacks Draft Picks\n by School Type", size = 28)
plt.xlabel("Year", size = 16)
plt.ylabel("School Type %", size = 16)
plt.yticks(np.arange(0, 101, step = 10))
plt.legend(["College", "High School", "Juco"], loc = "lower right", fontsize = 16)
plt.grid(color = "whitesmoke", linestyle = "-", axis = "y")
plt.savefig("Diamondbacks Draft Picks by School Type.png")
plt.show()
