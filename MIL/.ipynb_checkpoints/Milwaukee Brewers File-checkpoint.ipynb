# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#Original Draft Data

master_data = pd.read_csv("../starting file/Draft_SD_CSV.csv")
# Out:
# C:\Users\daily\Anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#Creating WAR Group Column

master_data.loc[(master_data["Total_WAR"] < 5), "WAR Group"] = "Less than 5 WAR"
master_data.loc[(master_data["Total_WAR"] < 10) & (master_data["Total_WAR"] >= 5), "WAR Group"] = "5-10 WAR"
master_data.loc[(master_data["Total_WAR"] < 15) & (master_data["Total_WAR"] >= 10), "WAR Group"] = "10-15 WAR"
master_data.loc[(master_data["Total_WAR"] < 20) & (master_data["Total_WAR"] >= 15), "WAR Group"] = "15-20 WAR"
master_data.loc[(master_data["Total_WAR"] < 25) & (master_data["Total_WAR"] >= 20), "WAR Group"] = "20-25 WAR"
master_data.loc[(master_data["Total_WAR"] >= 25), "WAR Group"] = "More than 25 WAR"
master_data["WAR Group"].fillna("No Major League Experience", inplace = True)

# %%
#Limiting the data to only Brewers players

brewers_data = master_data.loc[master_data["Franchise"] == "Brewers"]

#Only showing players that signed with the Brewers

signed_brewers_data = brewers_data.loc[brewers_data["Signed"] == "Y"]

#Grouped by draft class

draft_class_year = signed_brewers_data.groupby("Year")

#Unsigned Brewers draft picks

unsigned_brewers_data = brewers_data.loc[brewers_data["Signed"] == "N"]

# %%
#Total WAR by draft class sorted by best to worst

draft_class_year["Total_WAR"].sum().sort_values(ascending = False)
# Out:
# Year
# 2005    46.1
# 1977    40.5
# 2004    37.6
# 2007    35.5
# 1987    34.0
# 2009    28.6
# 1991    27.3
# 2002    26.9
# 1974    26.2
# 1999    25.1
# 1969    24.0
# 2001    22.7
# 1976    21.8
# 1983    19.3
# 2008    19.2
# 1986    17.8
# 1973    17.3
# 1995    16.8
# 1994    15.9
# 2003    15.7
# 1970    15.3
# 2012    12.9
# 1980    12.3
# 1985    11.1
# 1998    10.2
# 1992     9.5
# 1989     9.2
# 1993     9.2
# 2000     8.5
# 1984     8.0
# 1981     7.8
# 2010     7.7
# 1971     7.5
# 2014     5.8
# 1979     3.3
# 1968     2.2
# 2017     2.1
# 1988     1.9
# 2011     1.8
# 1997     1.6
# 2013     1.6
# 2006     1.5
# 2015     0.6
# 1972     0.5
# 2018     0.0
# 1975     0.0
# 2019     0.0
# 2016    -0.1
# 1978    -0.3
# 1996    -1.4
# 1990    -1.7
# 1982    -2.0
# Name: Total_WAR, dtype: float64

# %%
#WAR by draft class year bargraph

draft_class_year["Total_WAR"].sum().plot(kind = "bar", color = ["#0A2351", "#B6922E"], width = .8, fontsize = 12, edgecolor = "#0A2351", figsize = (16, 10.5))
plt.title("Milwaukee Brewers\n Total Draft Class WAR ", size = 28)
plt.xlabel("Draft Year", size = 16)
plt.ylabel("WAR", size = 16)
plt.yticks(np.arange(-10, 81, step = 5))
plt.grid(color = "whitesmoke", linestyle = "-", axis = "y")
plt.savefig("Brewers WAR Total by Draft Year.png")
plt.show()

# %%
#Best draft picks in franchise history

signed_brewers_data.sort_values(["Total_WAR"],ascending = False).head(10)
# Out:
#        Year  Rnd  OvPck       Tm Franchise Signed             Name  \
# 48797  2007    3    101  Brewers   Brewers      Y  Jonathan Lucroy
# 45698  2005    1      5  Brewers   Brewers      Y       Ryan Braun
# 24216  1991   11    286  Brewers   Brewers      Y     Jeff Cirillo
# 36832  1999    1     10  Brewers   Brewers      Y       Ben Sheets
# 9931   1977    1      3  Brewers   Brewers      Y     Paul Molitor
# 41240  2002    1      7  Brewers   Brewers      Y   Prince Fielder
# 44241  2004    2     46  Brewers   Brewers      Y  Yovani Gallardo
# 9387   1976    8    172  Brewers   Brewers      Y    Lary Sorensen
# 18328  1987    3     71  Brewers   Brewers      Y    Jaime Navarro
# 39804  2001    2     56  Brewers   Brewers      Y       J.J. Hardy
#
#        Debut_Year   playerID      fg_id  Hitting_WAR  Pitching_WAR  Total_WAR  \
# 48797      2010.0  lucrojo01     7870.0         36.9           0.0       36.9
# 45698      2007.0  braunry02     3410.0         31.2           0.0       31.2
# 24216      1994.0  cirilje01     1073.0         25.8           0.0       25.8
# 36832      2001.0  sheetbe01      710.0         -2.5          27.1       24.6
# 9931       1978.0  molitpa01  1009040.0         21.6           0.0       21.6
# 41240      2005.0  fieldpr01     4613.0         20.0           0.0       20.0
# 44241      2007.0  gallayo01     8173.0          3.2          15.9       19.1
# 9387       1977.0  sorenla01  1012279.0         -0.4          18.8       18.4
# 18328      1989.0  navarja01  1009465.0          0.2          17.7       17.9
# 39804      2005.0  hardyjj01     3797.0         17.6           0.0       17.6
#
#        Pos Type                                School          City State  \
# 48797    C  4Yr  University of Louisiana at Lafayette     Lafayette    LA
# 45698   3B  4Yr                   University of Miami  Coral Gables    FL
# 24216   3B  4Yr     University of Southern California   Los Angeles    CA
# 36832  RHP  4Yr     University of Louisiana at Monroe        Monroe    LA
# 9931    SS  4Yr               University of Minnesota   Minneapolis    MN
# 41240   1B   HS                         Eau Gallie HS     Melbourne    FL
# 44241  RHP   HS                  Trimble Technical HS    Fort Worth    TX
# 9387   RHP  4Yr                University of Michigan     Ann Arbor    MI
# 18328  RHP   JC                    Miami-Dade College         Miami    FL
# 39804   SS   HS                             Sabino HS        Tucson    AZ
#
#               WAR Group
# 48797  More than 25 WAR
# 45698  More than 25 WAR
# 24216  More than 25 WAR
# 36832         20-25 WAR
# 9931          20-25 WAR
# 41240         20-25 WAR
# 44241         15-20 WAR
# 9387          15-20 WAR
# 18328         15-20 WAR
# 39804         15-20 WAR

# %%
#Biggest draft busts found by looking at first rounders who had less than 5 WAR or didn't make majors

signed_brewers_data.loc[((signed_brewers_data["WAR Group"] == "Less than 5 WAR") |
(signed_brewers_data["WAR Group"] == "No Major League Experience")) & 
(signed_brewers_data["Rnd"] == 1)]
# Out:
#        Year  Rnd  OvPck       Tm Franchise Signed               Name  \
# 5513   1971    1      3  Brewers   Brewers      Y       Tommy Bianco
# 6317   1972    1      6  Brewers   Brewers      Y         Dan Thomas
# 7855   1974    1      6  Brewers   Brewers      Y         Butch Edge
# 8541   1975    1      5  Brewers   Brewers      Y      Rick O'Keeffe
# 10711  1978    1      8  Brewers   Brewers      Y     Nick Hernandez
# 12377  1980    1     25  Brewers   Brewers      Y         Dion James
# 14062  1982    1     25  Brewers   Brewers      Y         Dale Sveum
# 15713  1984    1     18  Brewers   Brewers      Y       Isaiah Clark
# 18270  1987    1     13  Brewers   Brewers      Y        Bill Spiers
# 20983  1989    1     30  Brewers   Brewers      Y      Gordon Powell
# 23945  1991    1     15  Brewers   Brewers      Y            Ty Hill
# 25541  1992    1     12  Brewers   Brewers      Y         Ken Felder
# 25567  1992    1     38  Brewers   Brewers      Y     Gabby Martinez
# 26967  1993    1     26  Brewers   Brewers      Y       Kelly Wunsch
# 26976  1993    1     35  Brewers   Brewers      Y          Todd Dunn
# 26980  1993    1     39  Brewers   Brewers      Y         Joe Wagner
# 28666  1994    1      4  Brewers   Brewers      Y  Antone Williamson
# 32040  1996    1      8  Brewers   Brewers      Y         Chad Green
# 33783  1997    1     13  Brewers   Brewers      Y      Kyle Peterson
# 35390  1998    1     13  Brewers   Brewers      Y          J.M. Gold
# 38307  2000    1     11  Brewers   Brewers      Y       Dave Krynzel
# 39760  2001    1     12  Brewers   Brewers      Y         Mike Jones
# 44200  2004    1      5  Brewers   Brewers      Y        Mark Rogers
# 47210  2006    1     16  Brewers   Brewers      Y    Jeremy Jeffress
# 48703  2007    1      7  Brewers   Brewers      Y       Matt LaPorta
# 50184  2008    1     35  Brewers   Brewers      Y  Evan Frederickson
# 51679  2009    1     26  Brewers   Brewers      Y        Eric Arnett
# 51692  2009    1     39  Brewers   Brewers      Y     Kentrail Davis
# 51700  2009    1     47  Brewers   Brewers      Y    Kyle Heckathorn
# 54711  2011    1     12  Brewers   Brewers      Y    Taylor Jungmann
# 54714  2011    1     15  Brewers   Brewers      Y        Jed Bradley
# 56256  2012    1     27  Brewers   Brewers      Y      Clint Coulter
# 56257  2012    1     28  Brewers   Brewers      Y      Victor Roache
# 58695  2014    1     12  Brewers   Brewers      Y      Kodi Medeiros
# 58724  2014    1     41  Brewers   Brewers      Y      Jake Gatewood
# 59913  2015    1     15  Brewers   Brewers      Y      Trent Grisham
# 59938  2015    1     40  Brewers   Brewers      Y       Nathan Kirby
# 61118  2016    1      5  Brewers   Brewers      Y          Corey Ray
# 62338  2017    1      9  Brewers   Brewers      Y       Keston Hiura
# 62363  2017    1     34  Brewers   Brewers      Y       Tristen Lutz
# 63565  2018    1     21  Brewers   Brewers      Y       Brice Turang
# 64786  2019    1     28  Brewers   Brewers      Y        Ethan Small
#
#        Debut_Year   playerID      fg_id  Hitting_WAR  Pitching_WAR  Total_WAR  \
# 5513       1975.0  biancto01  1000943.0         -0.3           0.0       -0.3
# 6317       1976.0  thomada01  1012970.0          0.8           0.0        0.8
# 7855       1979.0   edgebu01  1003672.0          0.0           0.3        0.3
# 8541          NaN        NaN        NaN          NaN           NaN        NaN
# 10711         NaN        NaN        NaN          NaN           NaN        NaN
# 12377      1983.0  jamesdi01  1006349.0          4.1           0.0        4.1
# 14062      1986.0  sveumda01  1012748.0         -0.6           0.0       -0.6
# 15713         NaN        NaN        NaN          NaN           NaN        NaN
# 18270      1989.0  spierbi01  1012338.0          0.8           0.0        0.8
# 20983         NaN        NaN        NaN          NaN           NaN        NaN
# 23945         NaN        NaN        NaN          NaN           NaN        NaN
# 25541         NaN        NaN        NaN          NaN           NaN        NaN
# 25567         NaN        NaN        NaN          NaN           NaN        NaN
# 26967      2000.0  wunscke01      259.0          0.0           1.0        1.0
# 26976      1996.0   dunnto01  1003579.0          0.0           0.0        0.0
# 26980         NaN        NaN        NaN          NaN           NaN        NaN
# 28666      1997.0  willian01  1013972.0         -0.7           0.0       -0.7
# 32040         NaN        NaN        NaN          NaN           NaN        NaN
# 33783      1999.0  peterky01  1010235.0          0.0           1.6        1.6
# 35390         NaN        NaN        NaN          NaN           NaN        NaN
# 38307      2004.0  krynzda01     8216.0          0.0           0.0        0.0
# 39760         NaN        NaN        NaN          NaN           NaN        NaN
# 44200      2010.0  rogerma01     4083.0          0.2           0.8        1.0
# 47210      2010.0  jeffrje01     9490.0          0.0           2.1        2.1
# 48703      2009.0  laporma01     2280.0         -1.3           0.0       -1.3
# 50184         NaN        NaN        NaN          NaN           NaN        NaN
# 51679         NaN        NaN        NaN          NaN           NaN        NaN
# 51692         NaN        NaN        NaN          NaN           NaN        NaN
# 51700         NaN        NaN        NaN          NaN           NaN        NaN
# 54711      2015.0  jungmta01    13119.0          0.4           1.3        1.7
# 54714      2016.0  bradlje01    13166.0          0.0           0.0        0.0
# 56256         NaN        NaN        NaN          NaN           NaN        NaN
# 56257         NaN        NaN        NaN          NaN           NaN        NaN
# 58695         NaN        NaN        NaN          NaN           NaN        NaN
# 58724         NaN        NaN        NaN          NaN           NaN        NaN
# 59913      2019.0  grishtr01    18564.0          0.6           0.0        0.6
# 59938         NaN        NaN        NaN          NaN           NaN        NaN
# 61118         NaN        NaN        NaN          NaN           NaN        NaN
# 62338      2019.0  hiurake01    20003.0          2.1           0.0        2.1
# 62363         NaN        NaN        NaN          NaN           NaN        NaN
# 63565         NaN        NaN        NaN          NaN           NaN        NaN
# 64786         NaN        NaN        NaN          NaN           NaN        NaN
#
#        Pos Type                                   School  \
# 5513    SS   HS                             Sewanhaka HS
# 6317    1B  4Yr  Southern Illinois University Carbondale
# 7855   RHP   HS                 El Camino Fundamental HS
# 8541   LHP   HS                      Yorktown Heights HS
# 10711    C   HS                               Hialeah HS
# 12377   OF   HS                             McClatchy HS
# 14062   SS   HS                         Pinole Valley HS
# 15713   SS   HS                              Crockett HS
# 18270   SS  4Yr                       Clemson University
# 20983   3B   HS                                Hughes HS
# 23945  LHP   HS                               Yucaipa HS
# 25541   OF  4Yr                 Florida State University
# 25567   SS   HS                              Luchetti HS
# 26967  LHP  4Yr                     Texas A&M University
# 26976   OF  4Yr              University of North Florida
# 26980  RHP  4Yr            University of Central Florida
# 28666   3B  4Yr                 Arizona State University
# 32040   OF  4Yr                   University of Kentucky
# 33783  RHP  4Yr                      Stanford University
# 35390  RHP   HS                      Toms River North HS
# 38307   OF   HS                          Green Valley HS
# 39760  RHP   HS                           Thunderbird HS
# 44200  RHP   HS                      Mount Ararat School
# 47210  RHP   HS                        Halifax County HS
# 48703   1B  4Yr                    University of Florida
# 50184  LHP  4Yr              University of San Francisco
# 51679  RHP  4Yr           Indiana University Bloomington
# 51692   CF  4Yr                  University of Tennessee
# 51700  RHP  4Yr                Kennesaw State University
# 54711  RHP  4Yr            University of Texas at Austin
# 54714  LHP  4Yr          Georgia Institute of Technology
# 56256    C   HS                                 Union HS
# 56257   OF  4Yr              Georgia Southern University
# 58695  LHP   HS                               Waiakea HS
# 58724   SS   HS                                Clovis HS
# 59913   OF   HS                              Richland HS
# 59938  LHP  4Yr                   University of Virginia
# 61118   OF  4Yr                 University of Louisville
# 62338   2B  4Yr          University of California Irvine
# 62363   OF   HS                       James W. Martin HS
# 63565   SS   HS                              Santiago HS
# 64786    P  4Yr             Mississippi State University
#
#                        City State                   WAR Group
# 5513            Floral Park    NY             Less than 5 WAR
# 6317             Carbondale    IL             Less than 5 WAR
# 7855             Sacramento    CA             Less than 5 WAR
# 8541       Yorktown Heights    NY  No Major League Experience
# 10711               Hialeah    FL  No Major League Experience
# 12377            Sacramento    CA             Less than 5 WAR
# 14062                Pinole    CA             Less than 5 WAR
# 15713              Crockett    TX  No Major League Experience
# 18270               Clemson    SC             Less than 5 WAR
# 20983            Cincinnati    OH  No Major League Experience
# 23945               Yucaipa    CA  No Major League Experience
# 25541           Tallahassee    FL  No Major League Experience
# 25567              Santurce    PR  No Major League Experience
# 26967       College Station    TX             Less than 5 WAR
# 26976          Jacksonville    FL             Less than 5 WAR
# 26980               Orlando    FL  No Major League Experience
# 28666                 Tempe    AZ             Less than 5 WAR
# 32040             Lexington    KY  No Major League Experience
# 33783             Palo Alto    CA             Less than 5 WAR
# 35390            Toms River    NJ  No Major League Experience
# 38307             Henderson    NV             Less than 5 WAR
# 39760               Phoenix    AZ  No Major League Experience
# 44200               Topsham    ME             Less than 5 WAR
# 47210          South Boston    VA             Less than 5 WAR
# 48703           Gainesville    FL             Less than 5 WAR
# 50184         San Francisco    CA  No Major League Experience
# 51679           Bloomington    IN  No Major League Experience
# 51692             Knoxville    TN  No Major League Experience
# 51700              Kennesaw    GA  No Major League Experience
# 54711                Austin    TX             Less than 5 WAR
# 54714               Atlanta    GA             Less than 5 WAR
# 56256                 Camas    WA  No Major League Experience
# 56257            Statesboro    GA  No Major League Experience
# 58695               Waiakea    HI  No Major League Experience
# 58724                Clovis    CA  No Major League Experience
# 59913  North Richland Hills    TX             Less than 5 WAR
# 59938       Charlottesville    VA  No Major League Experience
# 61118            Louisville    KY  No Major League Experience
# 62338                Irvine    CA             Less than 5 WAR
# 62363             Arlington    TX  No Major League Experience
# 63565                Corona    CA  No Major League Experience
# 64786            Starkville    MS  No Major League Experience

# %%
#Best unsigned draft picks in franchise history

unsigned_brewers_data.sort_values(["Total_WAR"],ascending = False).head(10)
# Out:
#        Year  Rnd  OvPck       Tm Franchise Signed               Name  \
# 24060  1991    5    130  Brewers   Brewers      N  Nomar Garciaparra
# 22071  1989   43   1118  Brewers   Brewers      N       Jason Giambi
# 42422  2002   40   1189  Brewers   Brewers      N       Hunter Pence
# 19544  1988    1     24  Brewers   Brewers      N     Alex Fernandez
# 26253  1992   26    724  Brewers   Brewers      N        Matt Morris
# 11179  1978   19    475  Brewers   Brewers      N   Kevin McReynolds
# 46468  2005   26    775  Brewers   Brewers      N       Jake Arrieta
# 18874  1987   24    617  Brewers   Brewers      N     Jeromy Burnitz
# 11102  1978   16    398  Brewers   Brewers      N         Tim Teufel
# 31868  1995   58   1501  Brewers   Brewers      N          Kip Wells
#
#        Debut_Year   playerID      fg_id  Hitting_WAR  Pitching_WAR  Total_WAR  \
# 24060      1996.0  garcino01      190.0         32.7           0.0       32.7
# 22071      1995.0  giambja01      818.0         28.4           0.0       28.4
# 42422      2007.0  pencehu01     8252.0         23.0           0.0       23.0
# 19544      1990.0  fernaal01  1003993.0          0.0          21.6       21.6
# 26253      1997.0  morrima01     1172.0          0.8          20.8       21.6
# 11179      1983.0  mcreyke01  1008690.0         20.7           0.0       20.7
# 46468      2010.0  arrieja01     4153.0          1.4          18.3       19.7
# 18874      1993.0  burnije01      867.0         14.8           0.0       14.8
# 11102      1983.0  teufeti01  1012940.0         11.7           0.0       11.7
# 31868      1999.0  wellski01     1012.0          0.7           9.7       10.4
#
#        Pos Type                    School            City State  \
# 24060   SS   HS         St. John Bosco HS      Bellflower    CA
# 22071   SS   HS            South Hills HS     West Covina    CA
# 42422   OF   JC         Texarkana College       Texarkana    TX
# 19544  RHP   HS  Monsignor Edward Pace HS   Miami Gardens    FL
# 26253  RHP   HS         Valley Central HS      Montgomery    NY
# 11179   OF   HS           Sylvan Hills HS        Sherwood    AR
# 46468  RHP   JC       Weatherford College     Weatherford    TX
# 18874    C   HS                 Conroe HS          Conroe    TX
# 11102   SS   JC    St. Petersburg College  St. Petersburg    FL
# 31868  RHP   HS      Lawrence E Elkins HS   Missouri City    TX
#
#               WAR Group
# 24060  More than 25 WAR
# 22071  More than 25 WAR
# 42422         20-25 WAR
# 19544         20-25 WAR
# 26253         20-25 WAR
# 11179         20-25 WAR
# 46468         15-20 WAR
# 18874         10-15 WAR
# 11102         10-15 WAR
# 31868         10-15 WAR

# %%
#Best Draft Picks outside the top 10 rounds

hidden_gems = signed_brewers_data.loc[signed_brewers_data["Rnd"] > 10].sort_values("Total_WAR", ascending = False)

hidden_gems.head(10)
# Out:
#        Year  Rnd  OvPck       Tm Franchise Signed             Name  \
# 24216  1991   11    286  Brewers   Brewers      Y     Jeff Cirillo
# 44691  2004   17    496  Brewers   Brewers      Y     Lorenzo Cain
# 3896   1969   15    357   Pilots   Brewers      Y       Jim Slaton
# 52149  2009   16    496  Brewers   Brewers      Y  Scooter Gennett
# 38617  2000   11    321  Brewers   Brewers      Y       Corey Hart
# 17635  1986   11    269  Brewers   Brewers      Y  Darryl Hamilton
# 16053  1984   14    358  Brewers   Brewers      Y        John Jaha
# 18588  1987   13    331  Brewers   Brewers      Y     Troy O'Leary
# 8117   1974   12    270  Brewers   Brewers      Y      Jim Gantner
# 52329  2009   22    676  Brewers   Brewers      Y       Mike Fiers
#
#        Debut_Year   playerID      fg_id  Hitting_WAR  Pitching_WAR  Total_WAR  \
# 24216      1994.0  cirilje01     1073.0         25.8           0.0       25.8
# 44691      2010.0   cainlo01     9077.0         17.4           0.0       17.4
# 3896       1971.0  slatoji01  1012054.0         -0.3          11.1       10.8
# 52149      2013.0  gennesc01    10339.0         10.3          -0.1       10.2
# 38617      2004.0   hartco01     1945.0          8.5           0.0        8.5
# 17635      1988.0  hamilda02  1005272.0          8.4           0.0        8.4
# 16053      1992.0   jahajo01  1006336.0          8.0           0.0        8.0
# 18588      1993.0  o'leatr01      789.0          7.3           0.0        7.3
# 8117       1976.0  gantnji01  1004483.0          7.0           0.0        7.0
# 52329      2011.0  fiersmi01     7754.0         -0.7           7.6        6.9
#
#        Pos Type                              School             City State  \
# 24216   3B  4Yr   University of Southern California      Los Angeles    CA
# 44691   OF   HS                   Madison County HS          Madison    FL
# 3896   RHP   JC             Antelope Valley College        Lancaster    CA
# 52149   SS   HS                         Sarasota HS         Sarasota    FL
# 38617   OF   HS                        Greenwood HS    Bowling Green    KY
# 17635   OF  4Yr           Nicholls State University        Thibodaux    LA
# 16053   3B   HS                          Douglas HS         Portland    OR
# 18588   OF   HS                          Cypress HS          Cypress    CA
# 8117    SS  4Yr  University of Wisconsin at Oshkosh          Oshkosh    WI
# 52329  RHP  4Yr        Nova Southeastern University  Fort Lauderdale    FL
#
#               WAR Group
# 24216  More than 25 WAR
# 44691         15-20 WAR
# 3896          10-15 WAR
# 52149         10-15 WAR
# 38617          5-10 WAR
# 17635          5-10 WAR
# 16053          5-10 WAR
# 18588          5-10 WAR
# 8117           5-10 WAR
# 52329          5-10 WAR

# %%
#Creating table for percentage of picks by school type

draft_year_school_table_pct = pd.crosstab(brewers_data["Year"], brewers_data["Type"], normalize = "index")

100 * round(draft_year_school_table_pct,3)
# Out:
# Type   4Yr    HS    JC
# Year
# 1968  22.2  66.7  11.1
# 1969  13.0  84.8   2.2
# 1970  10.7  89.3   0.0
# 1971   8.7  91.3   0.0
# 1972  28.6  71.4   0.0
# 1973   9.5  90.5   0.0
# 1974  37.5  62.5   0.0
# 1975  36.4  59.1   4.5
# 1976  43.5  56.5   0.0
# 1977  34.8  56.5   8.7
# 1978  43.3  43.3  13.3
# 1979  54.8  38.7   6.5
# 1980  44.0  44.0  12.0
# 1981  51.7  41.4   6.9
# 1982  53.3  33.3  13.3
# 1983  80.6  12.9   6.5
# 1984  44.8  48.3   6.9
# 1985  64.7  29.4   5.9
# 1986  50.0  41.7   8.3
# 1987  31.2  45.8  22.9
# 1988  57.1  31.0  11.9
# 1989  45.8  37.5  16.7
# 1990  60.0  25.0  15.0
# 1991  44.9  32.7  22.4
# 1992  44.9  40.8  14.3
# 1993  33.8  47.7  18.5
# 1994  31.1  49.2  19.7
# 1995  29.4  48.5  22.1
# 1996  33.3  40.4  26.3
# 1997  45.3  39.6  15.1
# 1998  49.0  40.8  10.2
# 1999  46.9  38.8  14.3
# 2000  42.9  38.8  18.4
# 2001  26.0  50.0  24.0
# 2002  40.5  33.3  26.2
# 2003  34.0  48.0  18.0
# 2004  25.0  58.3  16.7
# 2005  26.1  32.6  41.3
# 2006  34.7  44.9  20.4
# 2007  40.0  46.7  13.3
# 2008  46.3  42.6  11.1
# 2009  52.8  37.7   9.4
# 2010  62.0  28.0  10.0
# 2011  52.9  41.2   5.9
# 2012  57.1  35.7   7.1
# 2013  65.0  30.0   5.0
# 2014  48.8  43.9   7.3
# 2015  61.0  31.7   7.3
# 2016  70.7  22.0   7.3
# 2017  43.9  48.8   7.3
# 2018  30.0  55.0  15.0
# 2019  64.1  20.5  15.4

# %%
#Bar chart of table above

colors = ["#0A2351", "#B6922E", "white"]

(100 * round(draft_year_school_table_pct,3)).plot(kind = "bar", color = colors, width = .7, fontsize = 12, 
edgecolor = "#0A2351", stacked = True, figsize = (16, 10.5))
plt.title("Brewers Draft Picks\n by School Type", size = 28)
plt.xlabel("Year", size = 16)
plt.ylabel("School Type %", size = 16)
plt.yticks(np.arange(0, 101, step = 10))
plt.legend(["College", "High School", "Juco"], loc = "lower right", fontsize = 16)
plt.grid(color = "gainsboro", linestyle = "-", axis = "y")
plt.savefig("Brewers Draft Picks by School Type.png")
plt.show()
