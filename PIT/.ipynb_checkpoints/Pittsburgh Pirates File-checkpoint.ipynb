# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#Original Draft Data

master_data = pd.read_csv("../starting file/Draft_SD_CSV.csv")
# Out:
# C:\Users\daily\Anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#Creating WAR Group Column

master_data.loc[(master_data["Total_WAR"] < 5), "WAR Group"] = "Less than 5 WAR"
master_data.loc[(master_data["Total_WAR"] < 10) & (master_data["Total_WAR"] >= 5), "WAR Group"] = "5-10 WAR"
master_data.loc[(master_data["Total_WAR"] < 15) & (master_data["Total_WAR"] >= 10), "WAR Group"] = "10-15 WAR"
master_data.loc[(master_data["Total_WAR"] < 20) & (master_data["Total_WAR"] >= 15), "WAR Group"] = "15-20 WAR"
master_data.loc[(master_data["Total_WAR"] < 25) & (master_data["Total_WAR"] >= 20), "WAR Group"] = "20-25 WAR"
master_data.loc[(master_data["Total_WAR"] >= 25), "WAR Group"] = "More than 25 WAR"
master_data["WAR Group"].fillna("No Major League Experience", inplace = True)

# %%
#Limiting the data to only Pirates players

pirates_data = master_data.loc[master_data["Franchise"] == "Pirates"]

#Only showing players that signed with the Pirates

signed_pirates_data = pirates_data.loc[pirates_data["Signed"] == "Y"]

#Grouped by draft class

draft_class_year = signed_pirates_data.groupby("Year")

#Unsigned Pirates draft picks

unsigned_pirates_data = pirates_data.loc[pirates_data["Signed"] == "N"]

# %%
#Total WAR by draft class sorted by best to worst

round(draft_class_year["Total_WAR"].sum().sort_values(ascending = False),1)
# Out:
# Year
# 1985    46.7
# 1972    46.6
# 1966    42.3
# 2005    40.0
# 2011    37.3
# 1970    37.1
# 2000    34.7
# 1965    34.6
# 2001    28.1
# 2008    22.7
# 1996    21.6
# 1978    21.2
# 1992    19.6
# 1979    19.3
# 2003    19.2
# 1967    19.2
# 1968    19.2
# 1975    17.8
# 1988    16.0
# 2013    15.3
# 1983    15.3
# 2004    15.1
# 2002    13.4
# 1986    12.9
# 1976    10.5
# 2010    10.0
# 1974     9.8
# 1990     9.5
# 1989     9.1
# 1971     8.7
# 1973     8.5
# 1995     7.6
# 1980     6.4
# 1997     5.6
# 2009     4.4
# 2007     3.9
# 1994     3.3
# 2014     2.1
# 2012     1.9
# 1981     1.8
# 1998     1.2
# 1987     1.0
# 2015     0.9
# 1982     0.7
# 1977     0.7
# 1969     0.2
# 2017     0.0
# 2019     0.0
# 2018     0.0
# 2006    -0.0
# 1984    -0.1
# 2016    -0.2
# 1991    -0.3
# 1993    -0.5
# 1999    -5.7
# Name: Total_WAR, dtype: float64

# %%
#WAR by draft class year bargraph

draft_class_year["Total_WAR"].sum().plot(kind = "bar", color = ["#27251F", "#FDB827"], width = .8, fontsize = 12, edgecolor = "#27251F", figsize = (16, 10.5))
plt.title("Pittsburgh Pirates\n Total Draft Class WAR ", size = 28)
plt.xlabel("Draft Year", size = 16)
plt.ylabel("WAR", size = 16)
plt.yticks(np.arange(-10, 81, step = 5))
plt.grid(color = "whitesmoke", linestyle = "-", axis = "y")
plt.savefig("Pirates WAR Total by Draft Year.png")
plt.show()

# %%
#Best draft picks in franchise history

signed_pirates_data.sort_values(["Total_WAR"],ascending = False).head(10)
# Out:
#        Year  Rnd  OvPck       Tm Franchise Signed              Name  \
# 16540  1985    1      6  Pirates   Pirates      Y       Barry Bonds
# 45704  2005    1     11  Pirates   Pirates      Y  Andrew McCutchen
# 4917   1970   14    332  Pirates   Pirates      Y       Dave Parker
# 54700  2011    1      1  Pirates   Pirates      Y       Gerrit Cole
# 6478   1972    7    167  Pirates   Pirates      Y   Willie Randolph
# 25552  1992    1     23  Pirates   Pirates      Y     Jason Kendall
# 838    1966    1     15  Pirates   Pirates      Y     Richie Hebner
# 347    1965   18    348  Pirates   Pirates      Y         Bob Moose
# 1710   1967    3     56  Pirates   Pirates      Y       Richie Zisk
# 6358   1972    2     47  Pirates   Pirates      Y   John Candelaria
#
#        Debut_Year   playerID      fg_id  Hitting_WAR  Pitching_WAR  Total_WAR  \
# 16540      1986.0  bondsba01     1109.0         48.4           0.0       48.4
# 45704      2009.0  mccutan01     9847.0         41.0           0.0       41.0
# 4917       1973.0  parkeda01  1010000.0         31.3           0.0       31.3
# 54700      2013.0   colege01    13125.0          0.7          28.8       29.5
# 6478       1975.0  randowi01  1010694.0         27.6           0.0       27.6
# 25552      1996.0  kendaja01      993.0         22.5           0.0       22.5
# 838        1968.0  hebneri01  1005571.0         21.7           0.0       21.7
# 347        1967.0  moosebo01  1009134.0          0.0          20.4       20.4
# 1710       1971.0   ziskri01  1014455.0         19.3           0.0       19.3
# 6358       1975.0  candejo01  1001909.0          1.5          17.5       19.0
#
#        Pos Type                                School                   City  \
# 16540   OF  4Yr              Arizona State University                  Tempe
# 45704   OF   HS                         Fort Meade HS             Fort Meade
# 4917     C   HS                       Courter Tech HS             Cincinnati
# 54700  RHP  4Yr  University of California Los Angeles            Los Angeles
# 6478    SS   HS                             Tilden HS               Brooklyn
# 25552    C   HS                           Torrance HS               Torrance
# 838     SS   HS                            Norwood HS                Norwood
# 347    RHP   HS                           Franklin HS               Franklin
# 1710    OF   HS                         Parsippany HS  Parsippany-Troy Hills
# 6358   LHP   HS                       LaSalle Academy               Brooklyn
#
#       State         WAR Group
# 16540    AZ  More than 25 WAR
# 45704    FL  More than 25 WAR
# 4917     OH  More than 25 WAR
# 54700    CA  More than 25 WAR
# 6478     NY  More than 25 WAR
# 25552    CA         20-25 WAR
# 838      MA         20-25 WAR
# 347      PA         20-25 WAR
# 1710     NJ         15-20 WAR
# 6358     NY         15-20 WAR

# %%
#Biggest draft busts found by looking at first rounders who had less than 5 WAR or didn't make majors

signed_pirates_data.loc[((signed_pirates_data["WAR Group"] == "Less than 5 WAR") |
(signed_pirates_data["WAR Group"] == "No Major League Experience")) & 
(signed_pirates_data["Rnd"] == 1)]
# Out:
#        Year  Rnd  OvPck       Tm Franchise Signed                  Name  \
# 9      1965    1     10  Pirates   Pirates      Y       Wayne Dickerson
# 1670   1967    1     16  Pirates   Pirates      Y            Joe Grigas
# 2638   1968    1      9  Pirates   Pirates      Y           Dick Sharon
# 3551   1969    1     10  Pirates   Pirates      Y           John Morlan
# 4596   1970    1     13  Pirates   Pirates      Y           John Bedard
# 6334   1972    1     23  Pirates   Pirates      Y        Dwayne Peltier
# 7126   1973    1     24  Pirates   Pirates      Y         Steve Nicosia
# 7860   1974    1     11  Pirates   Pirates      Y            Rod Scurry
# 8556   1975    1     20  Pirates   Pirates      Y            Dale Berra
# 9236   1976    1     21  Pirates   Pirates      Y             Jim Parke
# 9946   1977    1     18  Pirates   Pirates      Y        Anthony Nicely
# 10722  1978    1     19  Pirates   Pirates      Y          Brad Garnett
# 10724  1978    1     21  Pirates   Pirates      Y           Jerry Aubin
# 12372  1980    1     20  Pirates   Pirates      Y         Rick Renteria
# 13198  1981    1     14  Pirates   Pirates      Y              Jim Winn
# 14044  1982    1      7  Pirates   Pirates      Y           Sam Khalifa
# 14880  1983    1     12  Pirates   Pirates      Y          Ron DeLucchi
# 15710  1984    1     15  Pirates   Pirates      Y         Kevin Andersh
# 18259  1987    1      2  Pirates   Pirates      Y         Mark Merchant
# 19533  1988    1     13  Pirates   Pirates      Y        Austin Manahan
# 20971  1989    1     18  Pirates   Pirates      Y         Willie Greene
# 22448  1990    1      5  Pirates   Pirates      Y           Kurt Miller
# 22470  1990    1     27  Pirates   Pirates      Y        Mike Zimmerman
# 23954  1991    1     24  Pirates   Pirates      Y           Jon Farrell
# 25562  1992    1     33  Pirates   Pirates      Y           Shon Walker
# 26963  1993    1     22  Pirates   Pirates      Y      Charles Peterson
# 26975  1993    1     34  Pirates   Pirates      Y  Jermaine Allensworth
# 26983  1993    1     42  Pirates   Pirates      Y          Charles Rice
# 28673  1994    1     11  Pirates   Pirates      Y           Mark Farris
# 30378  1995    1     10  Pirates   Pirates      Y        Chad Hermansen
# 33778  1997    1      8  Pirates   Pirates      Y            J.J. Davis
# 35392  1998    1     15  Pirates   Pirates      Y        Clint Johnston
# 36830  1999    1      8  Pirates   Pirates      Y         Bobby Bradley
# 38315  2000    1     19  Pirates   Pirates      Y          Sean Burnett
# 39756  2001    1      8  Pirates   Pirates      Y   John Van Benschoten
# 41234  2002    1      1  Pirates   Pirates      Y      Bryan Bullington
# 47198  2006    1      4  Pirates   Pirates      Y          Brad Lincoln
# 48700  2007    1      4  Pirates   Pirates      Y         Daniel Moskos
# 51657  2009    1      4  Pirates   Pirates      Y          Tony Sanchez
# 51702  2009    1     49  Pirates   Pirates      Y             Vic Black
# 56274  2012    1     45  Pirates   Pirates      Y        Barrett Barnes
# 57476  2013    1      9  Pirates   Pirates      Y        Austin Meadows
# 57481  2013    1     14  Pirates   Pirates      Y         Reese McGuire
# 58707  2014    1     24  Pirates   Pirates      Y           Cole Tucker
# 58722  2014    1     39  Pirates   Pirates      Y            Connor Joe
# 59917  2015    1     19  Pirates   Pirates      Y          Kevin Newman
# 59930  2015    1     32  Pirates   Pirates      Y        Ke'Bryan Hayes
# 61135  2016    1     22  Pirates   Pirates      Y            Will Craig
# 62341  2017    1     12  Pirates   Pirates      Y             Shane Baz
# 63554  2018    1     10  Pirates   Pirates      Y      Travis Swaggerty
# 64776  2019    1     18  Pirates   Pirates      Y        Quinn Priester
# 64795  2019    1     37  Pirates   Pirates      Y           Sammy Siani
#
#        Debut_Year   playerID      fg_id  Hitting_WAR  Pitching_WAR  Total_WAR  \
# 9             NaN        NaN        NaN          NaN           NaN        NaN
# 1670          NaN        NaN        NaN          NaN           NaN        NaN
# 2638       1973.0  sharodi01  1011806.0          0.9           0.0        0.9
# 3551       1973.0  morlajo01  1009191.0          0.0          -0.1       -0.1
# 4596          NaN        NaN        NaN          NaN           NaN        NaN
# 6334          NaN        NaN        NaN          NaN           NaN        NaN
# 7126       1978.0  nicosst01  1009575.0          1.6           0.0        1.6
# 7860       1980.0  scurrro01  1011700.0          0.0           2.9        2.9
# 8556       1977.0  berrada01  1000896.0          4.5           0.0        4.5
# 9236          NaN        NaN        NaN          NaN           NaN        NaN
# 9946          NaN        NaN        NaN          NaN           NaN        NaN
# 10722         NaN        NaN        NaN          NaN           NaN        NaN
# 10724         NaN        NaN        NaN          NaN           NaN        NaN
# 12372      1986.0  renteri01  1010838.0         -0.9           0.0       -0.9
# 13198      1983.0   winnji01  1014140.0         -0.1          -1.3       -1.4
# 14044      1985.0  khalisa01  1006887.0          0.7           0.0        0.7
# 14880         NaN        NaN        NaN          NaN           NaN        NaN
# 15710         NaN        NaN        NaN          NaN           NaN        NaN
# 18259         NaN        NaN        NaN          NaN           NaN        NaN
# 19533         NaN        NaN        NaN          NaN           NaN        NaN
# 20971      1992.0  greenwi01  1005015.0          4.8           0.0        4.8
# 22448      1994.0  milleku01  1008913.0          0.1          -0.6       -0.5
# 22470         NaN        NaN        NaN          NaN           NaN        NaN
# 23954         NaN        NaN        NaN          NaN           NaN        NaN
# 25562         NaN        NaN        NaN          NaN           NaN        NaN
# 26963         NaN        NaN        NaN          NaN           NaN        NaN
# 26975      1996.0  allenje01  1000148.0         -0.7           0.0       -0.7
# 26983         NaN        NaN        NaN          NaN           NaN        NaN
# 28673         NaN        NaN        NaN          NaN           NaN        NaN
# 30378      1999.0  hermach01      991.0         -2.5           0.0       -2.5
# 33778      2002.0  davisjj01     1597.0         -0.9           0.0       -0.9
# 35392         NaN        NaN        NaN          NaN           NaN        NaN
# 36830         NaN        NaN        NaN          NaN           NaN        NaN
# 38315      2004.0  burnese01     1886.0         -0.2           1.0        0.8
# 39756      2004.0  vanbejo01     2228.0          0.1          -0.7       -0.6
# 41234      2005.0  bullibr01     5066.0          0.0          -0.2       -0.2
# 47198      2010.0  lincobr01     4241.0          0.3           0.4        0.7
# 48700      2011.0  moskoda01     2858.0          0.0           0.2        0.2
# 51657      2013.0  sanchto01     6178.0          0.2           0.0        0.2
# 51702      2013.0  blackvi01     9195.0          0.0           0.2        0.2
# 56274         NaN        NaN        NaN          NaN           NaN        NaN
# 57476      2018.0  meadoau01    15672.0          4.2           0.0        4.2
# 57481      2018.0  mcguire01    15674.0          1.6           0.0        1.6
# 58707      2019.0  tuckeco01    17326.0          0.0           0.0        0.0
# 58722      2019.0    joeco01    16572.0         -0.2           0.0       -0.2
# 59917      2018.0  newmake01    17696.0          1.6           0.0        1.6
# 59930         NaN        NaN        NaN          NaN           NaN        NaN
# 61135         NaN        NaN        NaN          NaN           NaN        NaN
# 62341         NaN        NaN        NaN          NaN           NaN        NaN
# 63554         NaN        NaN        NaN          NaN           NaN        NaN
# 64776         NaN        NaN        NaN          NaN           NaN        NaN
# 64795         NaN        NaN        NaN          NaN           NaN        NaN
#
#        Pos Type                       School              City State  \
# 9       OF   HS                    Ensley HS        Birmingham    AL
# 1670    OF   HS                     Coyle HS          Brockton    MA
# 2638    OF   HS                   Sequoia HS      Redwood City    CA
# 3551   RHP   HS            Merritt Island HS    Merritt Island    FL
# 4596   RHP   HS          Springfield Tech HS       Springfield    MA
# 6334    SS   HS                   Servite HS           Anaheim    CA
# 7126     C   HS         North Miami Beach HS          Opalocka    FL
# 7860   LHP   HS                       Hug HS              Reno    NV
# 8556    SS   HS                 Montclair HS         Montclair    NJ
# 9236   RHP   HS             Henry Ford II HS  Sterling Heights    MI
# 9946    OF   HS                Meadowdale HS            Dayton    OH
# 10722   1B   HS                    DeSoto HS            DeSoto    TX
# 10724   OF   HS                 Dougherty HS            Albany    GA
# 12372   SS   HS                South Gate HS        South Gate    CA
# 13198  RHP  4Yr        John Brown University    Siloam Springs    AR
# 14044   SS   HS                   Sahuaro HS            Tucson    AZ
# 14880   OF   HS                Campolindo HS            Moraga    CA
# 15710  LHP  4Yr     University of New Mexico       Albuquerque    NM
# 18259   OF   HS                    Oviedo HS            Oviedo    FL
# 19533   SS   HS                   Horizon HS        Scottsdale    AZ
# 20971   SS   HS              Jones County HS              Gray    GA
# 22448  RHP   HS                      West HS       Bakersfield    CA
# 22470  RHP  4Yr  University of South Alabama            Mobile    AL
# 23954    C   JC              Florida College      Jacksonville    FL
# 25562   OF   HS           Harrison County HS         Cynthiana    KY
# 26963   OF   HS       Laurens District 55 HS           Laurens    SC
# 26975   OF  4Yr            Purdue University    West Lafayette    IN
# 26983   1B   HS                    Parker HS        Birmingham    AL
# 28673   SS   HS                  Angleton HS          Angleton    TX
# 30378   SS   HS              Green Valley HS         Henderson    NV
# 33778   1B   HS              Baldwin Park HS      Baldwin Park    CA
# 35392  LHP  4Yr        Vanderbilt University         Nashville    TN
# 36830  RHP   HS      Wellington Community HS        Wellington    FL
# 38315  LHP   HS      Wellington Community HS        Wellington    FL
# 39756  RHP  4Yr        Kent State University              Kent    OH
# 41234  RHP  4Yr        Ball State University            Muncie    IN
# 47198  RHP  4Yr        University of Houston           Houston    TX
# 48700  LHP  4Yr           Clemson University           Clemson    SC
# 51657    C  4Yr               Boston College     Chestnut Hill    MA
# 51702  RHP  4Yr    Dallas Baptist University            Dallas    TX
# 56274   OF  4Yr        Texas Tech University           Lubbock    TX
# 57476   CF   HS                   Grayson HS        Loganville    GA
# 57481    C   HS                  Kentwood HS         Covington    WA
# 58707   SS   HS           Mountain Pointe HS           Phoenix    AZ
# 58722   OF  4Yr      University of San Diego         San Diego    CA
# 59917   SS  4Yr        University of Arizona            Tucson    AZ
# 59930   3B   HS        Concordia Lutheran HS           Tomball    TX
# 61135   3B  4Yr       Wake Forest University     Winston-Salem    NC
# 62341  RHP   HS        Concordia Lutheran HS           Tomball    TX
# 63554   OF  4Yr  University of South Alabama            Mobile    AL
# 64776    P   HS                Cary-Grove HS              Cary    IL
# 64795   CF   HS  William Penn Charter School      Philadelphia    PA
#
#                         WAR Group
# 9      No Major League Experience
# 1670   No Major League Experience
# 2638              Less than 5 WAR
# 3551              Less than 5 WAR
# 4596   No Major League Experience
# 6334   No Major League Experience
# 7126              Less than 5 WAR
# 7860              Less than 5 WAR
# 8556              Less than 5 WAR
# 9236   No Major League Experience
# 9946   No Major League Experience
# 10722  No Major League Experience
# 10724  No Major League Experience
# 12372             Less than 5 WAR
# 13198             Less than 5 WAR
# 14044             Less than 5 WAR
# 14880  No Major League Experience
# 15710  No Major League Experience
# 18259  No Major League Experience
# 19533  No Major League Experience
# 20971             Less than 5 WAR
# 22448             Less than 5 WAR
# 22470  No Major League Experience
# 23954  No Major League Experience
# 25562  No Major League Experience
# 26963  No Major League Experience
# 26975             Less than 5 WAR
# 26983  No Major League Experience
# 28673  No Major League Experience
# 30378             Less than 5 WAR
# 33778             Less than 5 WAR
# 35392  No Major League Experience
# 36830  No Major League Experience
# 38315             Less than 5 WAR
# 39756             Less than 5 WAR
# 41234             Less than 5 WAR
# 47198             Less than 5 WAR
# 48700             Less than 5 WAR
# 51657             Less than 5 WAR
# 51702             Less than 5 WAR
# 56274  No Major League Experience
# 57476             Less than 5 WAR
# 57481             Less than 5 WAR
# 58707             Less than 5 WAR
# 58722             Less than 5 WAR
# 59917             Less than 5 WAR
# 59930  No Major League Experience
# 61135  No Major League Experience
# 62341  No Major League Experience
# 63554  No Major League Experience
# 64776  No Major League Experience
# 64795  No Major League Experience

# %%
#Best unsigned draft picks in franchise history

unsigned_pirates_data.sort_values(["Total_WAR"],ascending = False).head(10)
# Out:
#        Year  Rnd  OvPck       Tm Franchise Signed              Name  \
# 13906  1981   29    722  Pirates   Pirates      N       Chris Bosio
# 39375  2000   36   1079  Pirates   Pirates      N       Scott Baker
# 14098  1982    3     61  Pirates   Pirates      N       Joe Magrane
# 55301  2011   20    602  Pirates   Pirates      N       Trea Turner
# 13301  1981    5    117  Pirates   Pirates      N       Bip Roberts
# 13926  1981   30    742  Pirates   Pirates      N     Lance Johnson
# 40072  2001   11    324  Pirates   Pirates      N      Stephen Drew
# 59834  2014   38   1151  Pirates   Pirates      N       Paul DeJong
# 13613  1981   17    429  Pirates   Pirates      N    Scott Bankhead
# 10387  1977   18    459  Pirates   Pirates      N  Dennis Rasmussen
#
#        Debut_Year   playerID      fg_id  Hitting_WAR  Pitching_WAR  Total_WAR  \
# 13906      1986.0  bosioch01  1001212.0          0.0          20.5       20.5
# 39375      2005.0  bakersc02     6176.0          0.0          15.8       15.8
# 14098      1987.0  magrajo01  1007973.0          0.5          14.8       15.3
# 55301      2015.0  turnetr01    16252.0         14.3           0.0       14.3
# 13301      1986.0  roberbi01  1011023.0         13.6           0.0       13.6
# 13926      1987.0  johnsla03  1006482.0         12.7           0.0       12.7
# 40072      2006.0   drewst01     4251.0         10.9           0.0       10.9
# 59834      2017.0  dejonpa01    18015.0         10.5           0.0       10.5
# 13613      1986.0  bankhsc01  1000510.0          0.0          10.5       10.5
# 10387      1983.0  rasmude01  1010703.0          0.5           9.2        9.7
#
#        Pos Type                     School            City State  WAR Group
# 13906  RHP   HS                 Cordova HS  Rancho Cordova    CA  20-25 WAR
# 39375  RHP   HS          Captain Shreve HS      Shreveport    LA  15-20 WAR
# 14098  LHP   HS            Rowan County HS        Morehead    KY  15-20 WAR
# 55301   SS   HS    Park Vista Community HS      Lake Worth    FL  10-15 WAR
# 13301   SS   HS                 Skyline HS         Oakland    CA  10-15 WAR
# 13926   OF  NaN                        NaN             NaN   NaN  10-15 WAR
# 40072   SS   HS          Lowndes County HS        Valdosta    GA  10-15 WAR
# 59834    C  4Yr  Illinois State University          Normal    IL  10-15 WAR
# 13613  RHP   HS              Reidsville HS      Reidsville    NC  10-15 WAR
# 10387  LHP   HS              Bear Creek HS        Lakewood    CO   5-10 WAR

# %%
#Best Draft Picks outside the top 10 rounds

hidden_gems = signed_pirates_data.loc[signed_pirates_data["Rnd"] > 10].sort_values("Total_WAR", ascending = False)

hidden_gems.head(10)
# Out:
#        Year  Rnd  OvPck       Tm Franchise Signed            Name  Debut_Year  \
# 4917   1970   14    332  Pirates   Pirates      Y     Dave Parker      1973.0
# 347    1965   18    348  Pirates   Pirates      Y       Bob Moose      1967.0
# 15168  1983   12    300  Pirates   Pirates      Y     John Smiley      1986.0
# 434    1965   22    434  Pirates   Pirates      Y   Freddie Patek      1968.0
# 40342  2001   20    594  Pirates   Pirates      Y       Zach Duke      2005.0
# 9620   1976   17    405  Pirates   Pirates      Y  Rick Honeycutt      1977.0
# 42206  2002   33    973  Pirates   Pirates      Y    Nyjer Morgan      2007.0
# 2937   1968   14    309  Pirates   Pirates      Y     Bruce Kison      1971.0
# 11235  1978   21    531  Pirates   Pirates      Y   Dave Dravecky      1982.0
# 19980  1988   18    460  Pirates   Pirates      Y    Randy Tomlin      1990.0
#
#         playerID      fg_id  Hitting_WAR  Pitching_WAR  Total_WAR  Pos Type  \
# 4917   parkeda01  1010000.0         31.3           0.0       31.3    C   HS
# 347    moosebo01  1009134.0          0.0          20.4       20.4  RHP   HS
# 15168  smilejo01  1012084.0         -0.5          15.7       15.2  LHP   HS
# 434    patekfr01  1010052.0         13.7           0.0       13.7   SS  NaN
# 40342   dukeza01     3840.0          0.8          12.8       13.6  LHP   HS
# 9620   honeyri01  1005992.0         -0.1          11.2       11.1   1B  4Yr
# 42206  morgany01     4885.0         10.7           0.0       10.7   OF   JC
# 2937   kisonbr01  1006978.0          0.8           9.9       10.7  RHP   HS
# 11235  draveda01  1003486.0         -0.2          10.6       10.4  LHP  4Yr
# 19980  tomlira01  1013111.0          0.2           8.8        9.0  LHP  4Yr
#
#                               School         City State         WAR Group
# 4917                 Courter Tech HS   Cincinnati    OH  More than 25 WAR
# 347                      Franklin HS     Franklin    PA         20-25 WAR
# 15168               Perkiomen School    Pennsburg    PA         15-20 WAR
# 434                              NaN          NaN   NaN         10-15 WAR
# 40342                      Midway HS         Waco    TX         10-15 WAR
# 9620         University of Tennessee    Knoxville    TN         10-15 WAR
# 42206  Walla Walla Community College  Walla Walla    WA         10-15 WAR
# 2937                        Pasco HS        Pasco    WA         10-15 WAR
# 11235    Youngstown State University   Youngstown    OH         10-15 WAR
# 19980             Liberty University    Lynchburg    VA          5-10 WAR

# %%
#Creating table for percentage of picks by school type

draft_year_school_table_pct = pd.crosstab(pirates_data["Year"], pirates_data["Type"], normalize = "index")

100 * round(draft_year_school_table_pct,3)
# Out:
# Type   4Yr    HS    JC
# Year
# 1965  30.8  66.7   2.6
# 1966  31.6  68.4   0.0
# 1967  11.9  88.1   0.0
# 1968  13.2  84.2   2.6
# 1969  10.4  79.2  10.4
# 1970  15.5  77.6   6.9
# 1971  33.3  60.0   6.7
# 1972  23.1  71.8   5.1
# 1973  38.7  54.8   6.5
# 1974  30.6  63.9   5.6
# 1975  24.2  69.7   6.1
# 1976  47.2  47.2   5.6
# 1977  26.3  63.2  10.5
# 1978  30.8  66.7   2.6
# 1979  25.6  72.1   2.3
# 1980  31.0  61.9   7.1
# 1981  38.1  57.1   4.8
# 1982  38.2  55.9   5.9
# 1983  28.6  68.6   2.9
# 1984  45.2  50.0   4.8
# 1985  63.9  27.8   8.3
# 1986  64.7  29.4   5.9
# 1987  46.2  25.0  28.8
# 1988  46.2  26.2  27.7
# 1989  31.2  41.7  27.1
# 1990  52.5  40.0   7.5
# 1991  37.9  44.8  17.2
# 1992  47.1  39.2  13.7
# 1993  25.0  55.4  19.6
# 1994  32.6  54.3  13.0
# 1995  25.0  59.1  15.9
# 1996  25.9  57.4  16.7
# 1997  37.2  46.5  16.3
# 1998  25.5  63.8  10.6
# 1999  51.0  44.9   4.1
# 2000  16.3  59.2  24.5
# 2001  30.6  49.0  20.4
# 2002  37.2  48.8  14.0
# 2003  22.4  44.9  32.7
# 2004  34.0  50.0  16.0
# 2005  44.7  44.7  10.6
# 2006  46.9  34.7  18.4
# 2007  51.0  36.7  12.2
# 2008  51.0  34.7  14.3
# 2009  41.2  41.2  17.6
# 2010  34.0  52.0  14.0
# 2011  42.0  48.0  10.0
# 2012  43.9  43.9  12.2
# 2013  61.0  24.4  14.6
# 2014  69.0  21.4   9.5
# 2015  70.7  12.2  17.1
# 2016  78.0  14.6   7.3
# 2017  64.3  19.0  16.7
# 2018  75.6  24.4   0.0
# 2019  73.8  19.0   7.1

# %%
#Bar chart of table above

colors = ["#27251F", "#FDB827", "#E4002B"]

(100 * round(draft_year_school_table_pct,3)).plot(kind = "bar", color = colors, width = .7, fontsize = 12, 
edgecolor = "#27251F", stacked = True, figsize = (16, 10.5))
plt.title("Pirates Draft Picks\n by School Type", size = 28)
plt.xlabel("Year", size = 16)
plt.ylabel("School Type %", size = 16)
plt.yticks(np.arange(0, 101, step = 10))
plt.legend(["College", "High School", "Juco"], loc = "lower right", fontsize = 16)
plt.grid(color = "whitesmoke", linestyle = "-", axis = "y")
plt.savefig("Pirates Draft Picks by School Type.png")
plt.show()
