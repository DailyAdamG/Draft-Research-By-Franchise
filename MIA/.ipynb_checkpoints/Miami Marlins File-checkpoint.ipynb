# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#Original Draft Data

master_data = pd.read_csv("../starting file/Draft_SD_CSV.csv")
# Out:
# C:\Users\daily\Anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#Creating WAR Group Column

master_data.loc[(master_data["Total_WAR"] < 5), "WAR Group"] = "Less than 5 WAR"
master_data.loc[(master_data["Total_WAR"] < 10) & (master_data["Total_WAR"] >= 5), "WAR Group"] = "5-10 WAR"
master_data.loc[(master_data["Total_WAR"] < 15) & (master_data["Total_WAR"] >= 10), "WAR Group"] = "10-15 WAR"
master_data.loc[(master_data["Total_WAR"] < 20) & (master_data["Total_WAR"] >= 15), "WAR Group"] = "15-20 WAR"
master_data.loc[(master_data["Total_WAR"] < 25) & (master_data["Total_WAR"] >= 20), "WAR Group"] = "20-25 WAR"
master_data.loc[(master_data["Total_WAR"] >= 25), "WAR Group"] = "More than 25 WAR"
master_data["WAR Group"].fillna("No Major League Experience", inplace = True)

# %%
#Limiting the data to only Marlins players

marlins_data = master_data.loc[master_data["Franchise"] == "Marlins"]

#Only showing players that signed with the Marlins

signed_marlins_data = marlins_data.loc[marlins_data["Signed"] == "Y"]

#Grouped by draft class

draft_class_year = signed_marlins_data.groupby("Year")

#Unsigned Marlins draft picks

unsigned_marlins_data = marlins_data.loc[marlins_data["Signed"] == "N"]

# %%
#Total WAR by draft class sorted by best to worst

draft_class_year["Total_WAR"].sum().sort_values(ascending = False)
# Out:
# Year
# 2010    56.0
# 2007    33.2
# 2000    29.5
# 1999    27.6
# 2002    24.2
# 2011    23.1
# 1996    18.9
# 1992    18.9
# 1995    13.6
# 2005     9.5
# 2006     7.5
# 2008     7.2
# 2004     7.1
# 2012     6.9
# 2013     6.7
# 2014     6.0
# 2009     4.1
# 1994     1.8
# 2015     1.5
# 2001     0.9
# 1998     0.5
# 2018     0.0
# 2016     0.0
# 2017     0.0
# 2019     0.0
# 1993    -0.3
# 2003    -1.3
# 1997    -1.4
# Name: Total_WAR, dtype: float64

# %%
#WAR by draft class year bargraph

draft_class_year["Total_WAR"].sum().plot(kind = "bar", color = ["#00A3E0", "#000000"], width = .8, fontsize = 12, edgecolor = "#00A3E0", figsize = (16, 10.5))
plt.title("Miami Marlins\n Total Draft Class WAR ", size = 28)
plt.xlabel("Draft Year", size = 16)
plt.ylabel("WAR", size = 16)
plt.yticks(np.arange(-10, 101, step = 5))
plt.grid(color = "whitesmoke", linestyle = "-", axis = "y")
plt.savefig("Marlins WAR Total by Draft Year.png")
plt.show()

# %%
#Best draft picks in franchise history

signed_marlins_data.sort_values(["Total_WAR"],ascending = False).head(10)
# Out:
#        Year  Rnd  OvPck       Tm Franchise Signed               Name  \
# 53197  2010    1     23  Marlins   Marlins      Y   Christian Yelich
# 48772  2007    2     76  Marlins   Marlins      Y  Giancarlo Stanton
# 36824  1999    1      2  Marlins   Marlins      Y       Josh Beckett
# 25557  1992    1     28  Marlins   Marlins      Y    Charles Johnson
# 32041  1996    1      9  Marlins   Marlins      Y        Mark Kotsay
# 38297  2000    1      1  Marlins   Marlins      Y    Adrian Gonzalez
# 41346  2002    4    113  Marlins   Marlins      Y       Josh Johnson
# 53278  2010    3    104  Marlins   Marlins      Y      J.T. Realmuto
# 54713  2011    1     14  Marlins   Marlins      Y     Jose Fernandez
# 30433  1995    3     65  Marlins   Marlins      Y         Randy Winn
#
#        Debut_Year   playerID    fg_id  Hitting_WAR  Pitching_WAR  Total_WAR  \
# 53197      2013.0  yelicch01  11477.0         33.6           0.0       33.6
# 48772      2010.0  stantmi03   4949.0         27.3           0.0       27.3
# 36824      2001.0  beckejo02    510.0          0.4          20.4       20.8
# 25557      1994.0  johnsch04    523.0         19.9           0.0       19.9
# 32041      1997.0  kotsama01   1042.0         19.0           0.0       19.0
# 38297      2004.0  gonzaad01   1908.0         18.2           0.0       18.2
# 41346      2005.0  johnsjo09   4567.0          0.1          18.1       18.2
# 53278      2014.0  realmjt01  11739.0         17.2           0.0       17.2
# 54713      2013.0  fernajo02  11530.0          1.0          14.5       15.5
# 30433      1998.0   winnra01   1235.0         12.9           0.0       12.9
#
#        Pos Type                                 School              City  \
# 53197   1B   HS                            Westlake HS  Westlake Village
# 48772   1B   HS                          Notre Dame HS      Sherman Oaks
# 36824  RHP   HS                              Spring HS            Spring
# 25557    C  4Yr                    University of Miami      Coral Gables
# 32041   OF  4Yr  California State University Fullerton         Fullerton
# 38297   1B   HS                            Eastlake HS       Chula Vista
# 41346  RHP   HS                               Jenks HS             Jenks
# 53278   SS   HS                         Carl Albert HS      Midwest City
# 54713  RHP   HS                      Braulio Alonso HS             Tampa
# 30433   OF  4Yr                 Santa Clara University       Santa Clara
#
#       State         WAR Group
# 53197    CA  More than 25 WAR
# 48772    CA  More than 25 WAR
# 36824    TX         20-25 WAR
# 25557    FL         15-20 WAR
# 32041    CA         15-20 WAR
# 38297    CA         15-20 WAR
# 41346    OK         15-20 WAR
# 53278    OK         15-20 WAR
# 54713    FL         15-20 WAR
# 30433    CA         10-15 WAR

# %%
#Biggest draft busts found by looking at first rounders who had less than 5 WAR or didn't make majors

signed_marlins_data.loc[((signed_marlins_data["WAR Group"] == "Less than 5 WAR") |
(signed_marlins_data["WAR Group"] == "No Major League Experience")) & 
(signed_marlins_data["Rnd"] == 1)]
# Out:
#        Year  Rnd  OvPck       Tm Franchise Signed               Name  \
# 26968  1993    1     27  Marlins   Marlins      Y        Marc Valdes
# 28667  1994    1      5  Marlins   Marlins      Y         Josh Booty
# 30374  1995    1      6  Marlins   Marlins      Y        Jaime Jones
# 33782  1997    1     12  Marlins   Marlins      Y         Aaron Akin
# 35404  1998    1     27  Marlins   Marlins      Y        Chip Ambres
# 41244  2002    1     11  Marlins   Marlins      Y     Jeremy Hermida
# 42731  2003    1     16  Marlins   Marlins      Y       Jeff Allison
# 44222  2004    1     27  Marlins   Marlins      Y  Taylor Tankersley
# 45709  2005    1     16  Marlins   Marlins      Y      Chris Volstad
# 45715  2005    1     22  Marlins   Marlins      Y     Aaron Thompson
# 45722  2005    1     29  Marlins   Marlins      Y     Jacob Marceaux
# 45727  2005    1     34  Marlins   Marlins      Y        Ryan Tucker
# 45737  2005    1     44  Marlins   Marlins      Y          Sean West
# 47213  2006    1     19  Marlins   Marlins      Y     Brett Sinkbeil
# 48708  2007    1     12  Marlins   Marlins      Y     Matt Dominguez
# 50155  2008    1      6  Marlins   Marlins      Y     Kyle Skipworth
# 51671  2009    1     18  Marlins   Marlins      Y         Chad James
# 56238  2012    1      9  Marlins   Marlins      Y      Andrew Heaney
# 57473  2013    1      6  Marlins   Marlins      Y        Colin Moran
# 58685  2014    1      2  Marlins   Marlins      Y        Tyler Kolek
# 58719  2014    1     36  Marlins   Marlins      Y     Blake Anderson
# 59910  2015    1     12  Marlins   Marlins      Y        Josh Naylor
# 61120  2016    1      7  Marlins   Marlins      Y    Braxton Garrett
# 62342  2017    1     13  Marlins   Marlins      Y      Trevor Rogers
# 62365  2017    1     36  Marlins   Marlins      Y       Brian Miller
# 63557  2018    1     13  Marlins   Marlins      Y       Connor Scott
# 64762  2019    1      4  Marlins   Marlins      Y          JJ Bleday
# 64793  2019    1     35  Marlins   Marlins      Y     Kameron Misner
#
#        Debut_Year   playerID      fg_id  Hitting_WAR  Pitching_WAR  Total_WAR  \
# 26968      1995.0  valdema01  1013313.0         -0.2           0.6        0.4
# 28667      1996.0  bootyjo01  1001193.0          0.1           0.0        0.1
# 30374         NaN        NaN        NaN          NaN           NaN        NaN
# 33782         NaN        NaN        NaN          NaN           NaN        NaN
# 35404      2005.0  ambrech01     2042.0         -0.4           0.0       -0.4
# 41244      2005.0  hermije01     7208.0          1.8           0.0        1.8
# 42731         NaN        NaN        NaN          NaN           NaN        NaN
# 44222      2006.0  tanketa01     8249.0          0.0          -0.6       -0.6
# 45709      2008.0  volstch01     9901.0         -0.5           3.5        3.0
# 45715      2011.0  thompaa01      999.0          0.0           0.2        0.2
# 45722         NaN        NaN        NaN          NaN           NaN        NaN
# 45727      2008.0  tuckery01     1062.0         -0.1          -0.4       -0.5
# 45737      2009.0   westse01     4393.0         -0.3           1.0        0.7
# 47213      2010.0  sinkbbr01     9364.0          0.0          -0.1       -0.1
# 48708      2011.0  dominma01     4903.0         -0.8           0.0       -0.8
# 50155      2013.0  skipwky01     5298.0          0.0           0.0        0.0
# 51671         NaN        NaN        NaN          NaN           NaN        NaN
# 56238      2014.0  heanean01    15423.0         -0.1           4.6        4.5
# 57473      2016.0  moranco01    16909.0          0.7           0.0        0.7
# 58685         NaN        NaN        NaN          NaN           NaN        NaN
# 58719         NaN        NaN        NaN          NaN           NaN        NaN
# 59910      2019.0  naylojo01    18839.0         -0.2           0.0       -0.2
# 61120         NaN        NaN        NaN          NaN           NaN        NaN
# 62342         NaN        NaN        NaN          NaN           NaN        NaN
# 62365         NaN        NaN        NaN          NaN           NaN        NaN
# 63557         NaN        NaN        NaN          NaN           NaN        NaN
# 64762         NaN        NaN        NaN          NaN           NaN        NaN
# 64793         NaN        NaN        NaN          NaN           NaN        NaN
#
#        Pos Type                                       School  \
# 26968  RHP  4Yr                        University of Florida
# 28667   SS   HS                         Evangel Christian HS
# 30374   OF   HS                           Rancho Bernardo HS
# 33782  RHP   JC              Cowley County Community College
# 35404   OF   HS                                West Brook HS
# 41244   OF   HS                                   Wheeler HS
# 42731  RHP   HS                         Veterans Memorial HS
# 44222  LHP  4Yr                        University of Alabama
# 45709  RHP   HS                        Palm Beach Gardens HS
# 45715  LHP   HS                        Second Baptist School
# 45722  RHP  4Yr                     McNeese State University
# 45727  RHP   HS                               Temple City HS
# 45737  LHP   HS                            Captain Shreve HS
# 47213  RHP  4Yr                    Missouri State University
# 48708   3B   HS                                Chatsworth HS
# 50155    C   HS                                   Patriot HS
# 51671  LHP   HS                                     Yukon HS
# 56238  LHP  4Yr                    Oklahoma State University
# 57473   3B  4Yr  University of North Carolina at Chapel Hill
# 58685  RHP   HS                                  Shepherd HS
# 58719    C   HS                           West Lauderdale HS
# 59910   1B   HS                  St. Joan of Arc Catholic SS
# 61120  LHP   HS                                  Florence HS
# 62342  LHP   HS                                  Carlsbad HS
# 62365   OF  4Yr  University of North Carolina at Chapel Hill
# 63557   OF   HS                               H. B. Plant HS
# 64762   OF  4Yr                        Vanderbilt University
# 64793   CF  4Yr                       University of Missouri
#
#                      City State                   WAR Group
# 26968         Gainesville    FL             Less than 5 WAR
# 28667          Shreveport    LA             Less than 5 WAR
# 30374           San Diego    CA  No Major League Experience
# 33782       Arkansas City    KS  No Major League Experience
# 35404            Beaumont    TX             Less than 5 WAR
# 41244            Marietta    GA             Less than 5 WAR
# 42731             Peabody    MA  No Major League Experience
# 44222          Tuscaloosa    AL             Less than 5 WAR
# 45709  Palm Beach Gardens    FL             Less than 5 WAR
# 45715             Houston    TX             Less than 5 WAR
# 45722        Lake Charles    LA  No Major League Experience
# 45727         Temple City    CA             Less than 5 WAR
# 45737          Shreveport    LA             Less than 5 WAR
# 47213         Springfield    MO             Less than 5 WAR
# 48708          Chatsworth    CA             Less than 5 WAR
# 50155           Glen Avon    CA             Less than 5 WAR
# 51671               Yukon    OK  No Major League Experience
# 56238          Stillwater    OK             Less than 5 WAR
# 57473         Chapel Hill    NC             Less than 5 WAR
# 58685            Shepherd    TX  No Major League Experience
# 58719        Collinsville    MS  No Major League Experience
# 59910         Mississauga    ON             Less than 5 WAR
# 61120            Florence    AL  No Major League Experience
# 62342            Carlsbad    NM  No Major League Experience
# 62365         Chapel Hill    NC  No Major League Experience
# 63557               Tampa    FL  No Major League Experience
# 64762           Nashville    TN  No Major League Experience
# 64793            Columbia    MO  No Major League Experience

# %%
#Best unsigned draft picks in franchise history

unsigned_marlins_data.sort_values(["Total_WAR"],ascending = False).head(10)
# Out:
#        Year  Rnd  OvPck       Tm Franchise Signed              Name  \
# 45043  2004   28    848  Marlins   Marlins      N  Charlie Blackmon
# 34016  1997    8    246  Marlins   Marlins      N         Cliff Lee
# 52981  2009   44   1328  Marlins   Marlins      N         Ken Giles
# 38076  1999   42   1254  Marlins   Marlins      N      Adam LaRoche
# 35927  1998   18    550  Marlins   Marlins      N      Adam LaRoche
# 53882  2010   23    707  Marlins   Marlins      N     Blake Treinen
# 41198  2001   49   1450  Marlins   Marlins      N         Phil Coke
# 28210  1993   45   1269  Marlins   Marlins      N         Bob Howry
# 43398  2003   23    683  Marlins   Marlins      N       Tony Watson
# 57326  2012   36   1097  Marlins   Marlins      N  Kendall Graveman
#
#        Debut_Year   playerID    fg_id  Hitting_WAR  Pitching_WAR  Total_WAR  \
# 45043      2011.0  blackch02   7859.0         16.2           0.0       16.2
# 34016      2002.0    leecl02   1636.0         -0.2          14.9       14.7
# 52981      2014.0  gileske01  12910.0          0.0           9.7        9.7
# 38076      2004.0  larocad01   1904.0          7.2           0.0        7.2
# 35927      2004.0  larocad01   1904.0          7.2           0.0        7.2
# 53882      2014.0  treinbl01  12572.0         -0.1           6.2        6.1
# 41198      2008.0   cokeph01   5535.0          0.0           4.2        4.2
# 28210      1998.0  howrybo01    237.0          0.0           3.6        3.6
# 43398      2011.0  watsoto01   3132.0          0.0           3.5        3.5
# 57326      2014.0  graveke01  15514.0         -0.1           3.4        3.3
#
#        Pos Type                         School         City State  \
# 45043  LHP   HS              North Gwinnett HS      Suwanee    GA
# 34016  LHP   HS                      Benton HS       Benton    AR
# 52981  RHP   HS                  Rio Grande HS  Albuquerque    NM
# 38076   1B   JC   Fort Scott Community College   Fort Scott    KS
# 35927  LHP   HS                  Fort Scott HS   Fort Scott    KS
# 53882  RHP  4Yr  South Dakota State University    Brookings    SD
# 41198  LHP   HS                      Sonora HS       Sonora    CA
# 28210  RHP   JC                Yavapai College     Prescott    AZ
# 43398  LHP   HS        Dallas Center Grimes HS       Grimes    IA
# 57326  RHP  4Yr   Mississippi State University   Starkville    MS
#
#              WAR Group
# 45043        15-20 WAR
# 34016        10-15 WAR
# 52981         5-10 WAR
# 38076         5-10 WAR
# 35927         5-10 WAR
# 53882         5-10 WAR
# 41198  Less than 5 WAR
# 28210  Less than 5 WAR
# 43398  Less than 5 WAR
# 57326  Less than 5 WAR

# %%
#Best Draft Picks outside the top 10 rounds

hidden_gems = signed_marlins_data.loc[signed_marlins_data["Rnd"] > 10].sort_values("Total_WAR", ascending = False)

hidden_gems.head(10)
# Out:
#        Year  Rnd  OvPck       Tm Franchise Signed              Name  \
# 38787  2000   17    491  Marlins   Marlins      Y   Josh Willingham
# 52291  2009   21    638  Marlins   Marlins      Y          AJ Ramos
# 46359  2005   22    666  Marlins   Marlins      Y    Logan Morrison
# 50687  2008   18    538  Marlins   Marlins      Y       Tom Koehler
# 28020  1993   38   1079  Marlins   Marlins      Y         Dave Berg
# 36167  1998   26    790  Marlins   Marlins      Y       Kevin Olsen
# 30657  1995   11    289  Marlins   Marlins      Y       Gary Knotts
# 48159  2006   32    965  Marlins   Marlins      Y      Alex Sanabia
# 37148  1999   11    326  Marlins   Marlins      Y   Randy Messenger
# 47529  2006   11    335  Marlins   Marlins      Y  Osvaldo Martinez
#
#        Debut_Year   playerID   fg_id  Hitting_WAR  Pitching_WAR  Total_WAR  \
# 38787      2004.0  willijo03  2103.0         11.3           0.0       11.3
# 52291      2012.0  ramosaj01  8350.0          0.0           4.3        4.3
# 46359      2010.0  morrilo01  9205.0          2.9           0.0        2.9
# 50687      2012.0  koehlto01  6570.0         -1.1           4.0        2.9
# 28020      1998.0   bergda01  1288.0          1.2           0.0        1.2
# 36167      2001.0  olsenke01   533.0         -0.1           1.0        0.9
# 30657      2001.0  knottga01  1428.0          0.1           0.2        0.3
# 48159      2010.0  sanabal01  5350.0         -0.4           0.7        0.3
# 37148      2005.0  messera01  2658.0          0.0           0.2        0.2
# 47529      2010.0  martios01  3900.0          0.1           0.0        0.1
#
#        Pos Type                                       School          City  \
# 38787   SS  4Yr                  University of North Alabama      Florence
# 52291  RHP  4Yr                        Texas Tech University       Lubbock
# 46359   1B   HS                                Northshore HS       Slidell
# 50687  RHP  4Yr  State University of New York at Stony Brook   Stony Brook
# 28020   2B  4Yr                          University of Miami  Coral Gables
# 36167  RHP  4Yr                       University of Oklahoma        Norman
# 30657  RHP   HS                                    Brewer HS    Somerville
# 48159  RHP   HS                               Castle Park HS   Chula Vista
# 37148  RHP   HS                                    Sparks HS        Sparks
# 47529   SS   JC                          Porterville College   Porterville
#
#       State        WAR Group
# 38787    AL        10-15 WAR
# 52291    TX  Less than 5 WAR
# 46359    LA  Less than 5 WAR
# 50687    NY  Less than 5 WAR
# 28020    FL  Less than 5 WAR
# 36167    OK  Less than 5 WAR
# 30657    AL  Less than 5 WAR
# 48159    CA  Less than 5 WAR
# 37148    NV  Less than 5 WAR
# 47529    CA  Less than 5 WAR

# %%
#Creating table for percentage of picks by school type

draft_year_school_table_pct = pd.crosstab(marlins_data["Year"], marlins_data["Type"], normalize = "index")

100 * round(draft_year_school_table_pct,3)
# Out:
# Type   4Yr    HS    JC
# Year
# 1992  55.1  36.7   8.2
# 1993  25.3  51.6  23.1
# 1994  30.4  43.0  26.6
# 1995  28.6  51.2  20.2
# 1996  27.4  60.3  12.3
# 1997  21.1  54.4  24.6
# 1998  44.9  42.9  12.2
# 1999  36.0  44.0  20.0
# 2000  37.2  48.8  14.0
# 2001  40.8  44.9  14.3
# 2002  38.0  34.0  28.0
# 2003  33.3  39.6  27.1
# 2004  50.0  32.0  18.0
# 2005  49.0  29.4  21.6
# 2006  48.0  30.0  22.0
# 2007  40.0  36.0  24.0
# 2008  54.0  36.0  10.0
# 2009  52.0  40.0   8.0
# 2010  58.0  20.0  22.0
# 2011  52.0  22.0  26.0
# 2012  64.1  33.3   2.6
# 2013  57.1  26.2  16.7
# 2014  54.8  35.7   9.5
# 2015  65.0  32.5   2.5
# 2016  69.2  15.4  15.4
# 2017  82.9   9.8   7.3
# 2018  73.2  19.5   7.3
# 2019  75.6  19.5   4.9

# %%
#Bar chart of table above

colors = ["#00A3E0", "#000000", "#EF3340"]

(100 * round(draft_year_school_table_pct,3)).plot(kind = "bar", color = colors, width = .7, fontsize = 12, 
edgecolor = "#00A3E0", stacked = True, figsize = (16, 10.5))
plt.title("Marlins Draft Picks\n by School Type", size = 28)
plt.xlabel("Year", size = 16)
plt.ylabel("School Type %", size = 16)
plt.yticks(np.arange(0, 101, step = 10))
plt.legend(["College", "High School", "Juco"], loc = "lower right", fontsize = 16)
plt.grid(color = "whitesmoke", linestyle = "-", axis = "y")
plt.savefig("Marlins Draft Picks by School Type.png")
plt.show()
