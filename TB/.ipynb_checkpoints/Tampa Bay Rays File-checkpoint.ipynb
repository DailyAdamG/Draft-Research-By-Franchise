# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#Original Draft Data

master_data = pd.read_csv("../starting file/Draft_SD_CSV.csv")
# Out:
# C:\Users\daily\Anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#Creating WAR Group Column

master_data.loc[(master_data["Total_WAR"] < 5), "WAR Group"] = "Less than 5 WAR"
master_data.loc[(master_data["Total_WAR"] < 10) & (master_data["Total_WAR"] >= 5), "WAR Group"] = "5-10 WAR"
master_data.loc[(master_data["Total_WAR"] < 15) & (master_data["Total_WAR"] >= 10), "WAR Group"] = "10-15 WAR"
master_data.loc[(master_data["Total_WAR"] < 20) & (master_data["Total_WAR"] >= 15), "WAR Group"] = "15-20 WAR"
master_data.loc[(master_data["Total_WAR"] < 25) & (master_data["Total_WAR"] >= 20), "WAR Group"] = "20-25 WAR"
master_data.loc[(master_data["Total_WAR"] >= 25), "WAR Group"] = "More than 25 WAR"
master_data["WAR Group"].fillna("No Major League Experience", inplace = True)

# %%
#Limiting the data to only Rays players

rays_data = master_data.loc[master_data["Franchise"] == "Rays"]

#Only showing players that signed with the Rays

signed_rays_data = rays_data.loc[rays_data["Signed"] == "Y"]

#Grouped by draft class

draft_class_year = signed_rays_data.groupby("Year")

#Unsigned Rays draft picks

unsigned_rays_data = rays_data.loc[rays_data["Signed"] == "N"]

# %%
#Total WAR by draft class sorted by best to worst

draft_class_year["Total_WAR"].sum().sort_values(ascending = False)
# Out:
# Year
# 2006    59.2
# 1999    54.4
# 2007    35.0
# 2000    32.5
# 2010    29.9
# 2004    28.9
# 2002    27.5
# 1998    26.1
# 2011    10.3
# 2005     9.7
# 2001     5.5
# 2012     5.4
# 2008     5.2
# 1996     4.2
# 2015     3.6
# 1997     2.7
# 2013     2.5
# 2017     0.8
# 2003     0.5
# 2018     0.0
# 2019     0.0
# 2016    -0.3
# 2009    -0.9
# 2014    -0.9
# Name: Total_WAR, dtype: float64

# %%
#WAR by draft class year bargraph

draft_class_year["Total_WAR"].sum().plot(kind = "bar", color = ["#092C5C", "#8FBCE6"], width = .8, fontsize = 12, edgecolor = "#092C5C", figsize = (16, 10.5))
plt.title("Tampa Bay Rays\n Total Draft Class WAR ", size = 28)
plt.xlabel("Draft Year", size = 16)
plt.ylabel("WAR", size = 16)
plt.yticks(np.arange(-10, 81, step = 5))
plt.grid(color = "whitesmoke", linestyle = "-", axis = "y")
plt.savefig("Rays WAR Total by Draft Year.png")
plt.show()

# %%
#Best draft picks in franchise history

signed_rays_data.sort_values(["Total_WAR"],ascending = False).head(10)
# Out:
#        Year  Rnd  OvPck          Tm Franchise Signed              Name  \
# 47197  2006    1      3  Devil Rays      Rays      Y     Evan Longoria
# 36823  1999    1      1  Devil Rays      Rays      Y     Josh Hamilton
# 48697  2007    1      1  Devil Rays      Rays      Y       David Price
# 38762  2000   16    466  Devil Rays      Rays      Y     James Shields
# 36874  1999    2     52  Devil Rays      Rays      Y     Carl Crawford
# 54116  2010   31    941        Rays      Rays      Y   Kevin Kiermaier
# 41235  2002    1      2  Devil Rays      Rays      Y  Melvin Upton Jr.
# 47483  2006   10    289  Devil Rays      Rays      Y  Desmond Jennings
# 44270  2004    3     75  Devil Rays      Rays      Y        Wade Davis
# 54751  2011    1     52        Rays      Rays      Y       Blake Snell
#
#        Debut_Year   playerID    fg_id  Hitting_WAR  Pitching_WAR  Total_WAR  \
# 47197      2008.0  longoev01   9368.0         37.8           0.0       37.8
# 36823      2007.0  hamiljo03   1875.0         26.5           0.0       26.5
# 48697      2008.0  priceda01   3184.0         -0.1          24.4       24.3
# 38762      2006.0  shielja02   7059.0          0.1          23.9       24.0
# 36874      2002.0  crawfca02   1201.0         23.2           0.0       23.2
# 54116      2013.0  kiermke01  11038.0         17.5           0.0       17.5
# 41235      2004.0  uptonbj01   5015.0         15.4           0.0       15.4
# 47483      2010.0  jennide01   1965.0         11.7           0.0       11.7
# 44270      2009.0  daviswa01   7441.0          0.1          11.2       11.3
# 54751      2016.0  snellbl01  13543.0          0.1          11.0       11.1
#
#        Pos Type                                  School           City State  \
# 47197   3B  4Yr  California State University Long Beach     Long Beach    CA
# 36823   OF   HS                         Athens Drive HS        Raleigh    NC
# 48697  LHP  4Yr                   Vanderbilt University      Nashville    TN
# 38762  RHP   HS                      William S. Hart HS  Santa Clarita    CA
# 36874   OF   HS                      Jefferson Davis HS        Houston    TX
# 54116   RF   JC                        Parkland College      Champaign    IL
# 41235   SS   HS            Greenbrier Christian Academy     Chesapeake    VA
# 47483   OF   JC              Itawamba Community College         Fulton    MS
# 44270  RHP   HS                           Lake Wales HS     Lake Wales    FL
# 54751  LHP   HS                            Shorewood HS      Shoreline    WA
#
#               WAR Group
# 47197  More than 25 WAR
# 36823  More than 25 WAR
# 48697         20-25 WAR
# 38762         20-25 WAR
# 36874         20-25 WAR
# 54116         15-20 WAR
# 41235         15-20 WAR
# 47483         10-15 WAR
# 44270         10-15 WAR
# 54751         10-15 WAR

# %%
#Biggest draft busts found by looking at first rounders who had less than 5 WAR or didn't make majors

signed_rays_data.loc[((signed_rays_data["WAR Group"] == "Less than 5 WAR") |
(signed_rays_data["WAR Group"] == "No Major League Experience")) & 
(signed_rays_data["Rnd"] == 1)]
# Out:
#        Year  Rnd  OvPck          Tm Franchise Signed                Name  \
# 32061  1996    1     29        Rays      Rays      Y         Paul Wilder
# 33801  1997    1     31        Rays      Rays      Y    Jason Standridge
# 39751  2001    1      3  Devil Rays      Rays      Y     Dewon Brazelton
# 42716  2003    1      1  Devil Rays      Rays      Y        Delmon Young
# 45701  2005    1      8  Devil Rays      Rays      Y       Wade Townsend
# 50150  2008    1      1        Rays      Rays      Y         Tim Beckham
# 53191  2010    1     17        Rays      Rays      Y           Josh Sale
# 53205  2010    1     31        Rays      Rays      Y     Justin O'Conner
# 53216  2010    1     42        Rays      Rays      Y      Drew Vettleson
# 54723  2011    1     24        Rays      Rays      Y    Taylor Guerrieri
# 54730  2011    1     31        Rays      Rays      Y       Mikie Mahtook
# 54731  2011    1     32        Rays      Rays      Y          Jake Hager
# 54737  2011    1     38        Rays      Rays      Y      Brandon Martin
# 54740  2011    1     41        Rays      Rays      Y       Tyler Goeddel
# 54741  2011    1     42        Rays      Rays      Y           Jeff Ames
# 54755  2011    1     56        Rays      Rays      Y          Kes Carter
# 54758  2011    1     59        Rays      Rays      Y      Grayson Garvin
# 54759  2011    1     60        Rays      Rays      Y        James Harris
# 56254  2012    1     25        Rays      Rays      Y      Richie Shaffer
# 57488  2013    1     21        Rays      Rays      Y         Nick Ciuffo
# 57496  2013    1     29        Rays      Rays      Y         Ryne Stanek
# 58703  2014    1     20        Rays      Rays      Y     Casey Gillaspie
# 59911  2015    1     13        Rays      Rays      Y     Garrett Whitley
# 61126  2016    1     13        Rays      Rays      Y           Josh Lowe
# 62333  2017    1      4        Rays      Rays      Y       Brendan McKay
# 63560  2018    1     16        Rays      Rays      Y  Matthew Liberatore
# 63575  2018    1     31        Rays      Rays      Y    Shane McClanahan
# 63576  2018    1     32        Rays      Rays      Y        Nick Schnell
# 64780  2019    1     22        Rays      Rays      Y          Greg Jones
# 64794  2019    1     36        Rays      Rays      Y             JJ Goss
# 64798  2019    1     40        Rays      Rays      Y        Seth Johnson
#
#        Debut_Year   playerID    fg_id  Hitting_WAR  Pitching_WAR  Total_WAR  \
# 32061         NaN        NaN      NaN          NaN           NaN        NaN
# 33801      2001.0  standja01   1229.0          0.0          -1.0       -1.0
# 39751      2002.0  brazede01   1195.0          0.0          -0.8       -0.8
# 42716      2006.0  youngde03   2140.0         -1.2           0.0       -1.2
# 45701         NaN        NaN      NaN          NaN           NaN        NaN
# 50150      2013.0  beckhti01   7949.0          4.3           0.0        4.3
# 53191         NaN        NaN      NaN          NaN           NaN        NaN
# 53205         NaN        NaN      NaN          NaN           NaN        NaN
# 53216         NaN        NaN      NaN          NaN           NaN        NaN
# 54723      2018.0  guerrta02  13616.0          0.0          -0.1       -0.1
# 54730      2015.0  mahtomi01  13130.0          1.3           0.0        1.3
# 54731         NaN        NaN      NaN          NaN           NaN        NaN
# 54737         NaN        NaN      NaN          NaN           NaN        NaN
# 54740      2016.0  goeddty01  13180.0         -1.1           0.0       -1.1
# 54741         NaN        NaN      NaN          NaN           NaN        NaN
# 54755         NaN        NaN      NaN          NaN           NaN        NaN
# 54758         NaN        NaN      NaN          NaN           NaN        NaN
# 54759         NaN        NaN      NaN          NaN           NaN        NaN
# 56254      2015.0  shaffri01  13271.0          0.3           0.0        0.3
# 57488      2018.0  ciuffni01  16291.0         -0.2           0.0       -0.2
# 57496      2017.0  stanery01  15947.0          0.0           1.6        1.6
# 58703         NaN        NaN      NaN          NaN           NaN        NaN
# 59911         NaN        NaN      NaN          NaN           NaN        NaN
# 61126         NaN        NaN      NaN          NaN           NaN        NaN
# 62333      2019.0  mckaybr01  20186.0          0.0           0.8        0.8
# 63560         NaN        NaN      NaN          NaN           NaN        NaN
# 63575         NaN        NaN      NaN          NaN           NaN        NaN
# 63576         NaN        NaN      NaN          NaN           NaN        NaN
# 64780         NaN        NaN      NaN          NaN           NaN        NaN
# 64794         NaN        NaN      NaN          NaN           NaN        NaN
# 64798         NaN        NaN      NaN          NaN           NaN        NaN
#
#        Pos Type                                      School           City  \
# 32061   OF   HS                                     Cary HS           Cary
# 33801  RHP   HS                        Hewitt-Trussville HS     Trussville
# 39751  RHP  4Yr           Middle Tennessee State University   Murfreesboro
# 42716   OF   HS                         Adolfo Camarillo HS      Camarillo
# 45701  RHP  4Yr                             Rice University        Houston
# 50150   SS   HS                                  Griffin HS        Griffin
# 53191   RF   HS                          Bishop Blanchet HS        Seattle
# 53205    C   HS                                    Cowan HS         Muncie
# 53216   RF   HS                           Central Kitsap HS     Silverdale
# 54723  RHP   HS                            Spring Valley HS       Columbia
# 54730   OF  4Yr                  Louisiana State University    Baton Rouge
# 54731   SS   HS                             Sierra Vista HS      Las Vegas
# 54737   SS   HS                                 Santiago HS         Corona
# 54740   3B   HS                              St. Francis HS  Mountain View
# 54741  RHP   JC                      Lower Columbia College       Longview
# 54755   OF  4Yr                 Western Kentucky University  Bowling Green
# 54758  LHP  4Yr                       Vanderbilt University      Nashville
# 54759   OF   HS                        Oakland Technical HS        Oakland
# 56254   3B  4Yr                          Clemson University        Clemson
# 57488    C   HS                                Lexington HS      Lexington
# 57496  RHP  4Yr                      University of Arkansas   Fayetteville
# 58703   1B  4Yr                    Wichita State University        Wichita
# 59911   OF   HS                                Niskayuna HS      Niskayuna
# 61126   3B   HS                                     Pope HS       Marietta
# 62333   1B  4Yr                    University of Louisville     Louisville
# 63560  LHP   HS                           Mountain Ridge HS       Glendale
# 63575  LHP  4Yr                 University of South Florida          Tampa
# 63576   CF   HS                                 Roncalli HS   Indianapolis
# 64780   SS  4Yr  University of North Carolina at Wilmington     Wilmington
# 64794    P   HS                            Cypress Ranch HS        Cypress
# 64798    P  4Yr                         Campbell University    Buies Creek
#
#       State                   WAR Group
# 32061    NC  No Major League Experience
# 33801    AL             Less than 5 WAR
# 39751    TN             Less than 5 WAR
# 42716    CA             Less than 5 WAR
# 45701    TX  No Major League Experience
# 50150    GA             Less than 5 WAR
# 53191    WA  No Major League Experience
# 53205    IN  No Major League Experience
# 53216    WA  No Major League Experience
# 54723    SC             Less than 5 WAR
# 54730    LA             Less than 5 WAR
# 54731    NV  No Major League Experience
# 54737    CA  No Major League Experience
# 54740    CA             Less than 5 WAR
# 54741    WA  No Major League Experience
# 54755    KY  No Major League Experience
# 54758    TN  No Major League Experience
# 54759    CA  No Major League Experience
# 56254    SC             Less than 5 WAR
# 57488    SC             Less than 5 WAR
# 57496    AR             Less than 5 WAR
# 58703    KS  No Major League Experience
# 59911    NY  No Major League Experience
# 61126    GA  No Major League Experience
# 62333    KY             Less than 5 WAR
# 63560    AZ  No Major League Experience
# 63575    FL  No Major League Experience
# 63576    IN  No Major League Experience
# 64780    NC  No Major League Experience
# 64794    TX  No Major League Experience
# 64798    NC  No Major League Experience

# %%
#Best Draft Picks outside the top 10 rounds

hidden_gems = signed_rays_data.loc[signed_rays_data["Rnd"] > 10].sort_values("Total_WAR", ascending = False)

hidden_gems.head(10)
# Out:
#        Year  Rnd  OvPck          Tm Franchise Signed              Name  \
# 38762  2000   16    466  Devil Rays      Rays      Y     James Shields
# 54116  2010   31    941        Rays      Rays      Y   Kevin Kiermaier
# 44570  2004   13    375  Devil Rays      Rays      Y  Andy Sonnanstine
# 37327  1999   17    505  Devil Rays      Rays      Y         Matt Diaz
# 40757  2001   34   1009  Devil Rays      Rays      Y       Chad Gaudin
# 35929  1998   18    552  Devil Rays      Rays      Y     Brandon Backe
# 49061  2007   12    365  Devil Rays      Rays      Y      Stephen Vogt
# 40277  2001   18    529  Devil Rays      Rays      Y       Jonny Gomes
# 43053  2003   12    338  Devil Rays      Rays      Y         John Jaso
# 32516  1996   16    484        Rays      Rays      Y    Jared Sandberg
#
#        Debut_Year   playerID    fg_id  Hitting_WAR  Pitching_WAR  Total_WAR  \
# 38762      2006.0  shielja02   7059.0          0.1          23.9       24.0
# 54116      2013.0  kiermke01  11038.0         17.5           0.0       17.5
# 44570      2007.0  sonnaan01   7667.0          0.4           4.8        5.2
# 37327      2003.0   diazma02   1771.0          4.8           0.0        4.8
# 40757      2003.0  gaudich01   1783.0         -0.3           4.6        4.3
# 35929      2002.0  backebr01   1529.0          2.0           1.4        3.4
# 49061      2012.0   vogtst01   5000.0          3.3           0.0        3.3
# 40277      2003.0  gomesjo01   1845.0          2.7           0.0        2.7
# 43053      2008.0   jasojo01   5887.0          2.5           0.0        2.5
# 32516      2001.0  sandbja01   1224.0          2.5           0.0        2.5
#
#        Pos Type                     School           City State  \
# 38762  RHP   HS         William S. Hart HS  Santa Clarita    CA
# 54116   RF   JC           Parkland College      Champaign    IL
# 44570  RHP  4Yr      Kent State University           Kent    OH
# 37327   OF  4Yr   Florida State University    Tallahassee    FL
# 40757  RHP   HS   Crescent City Baptist HS        Harahan    LA
# 35929   SS   JC          Galveston College      Galveston    TX
# 49061   1B  4Yr   Azusa Pacific University          Azusa    CA
# 40277   OF   JC  Santa Rosa Junior College     Santa Rosa    CA
# 43053    C   JC       Southwestern College    Chula Vista    CA
# 32516   3B   HS                 Capital HS        Olympia    WA
#
#              WAR Group
# 38762        20-25 WAR
# 54116        15-20 WAR
# 44570         5-10 WAR
# 37327  Less than 5 WAR
# 40757  Less than 5 WAR
# 35929  Less than 5 WAR
# 49061  Less than 5 WAR
# 40277  Less than 5 WAR
# 43053  Less than 5 WAR
# 32516  Less than 5 WAR

# %%
#Creating table for percentage of picks by school type

draft_year_school_table_pct = pd.crosstab(rays_data["Year"], rays_data["Type"], normalize = "index")

100 * round(draft_year_school_table_pct,3)
# Out:
# Type   4Yr    HS    JC
# Year
# 1996  28.1  54.2  17.7
# 1997  16.3  57.6  26.1
# 1998  19.1  42.6  38.3
# 1999  20.0  62.0  18.0
# 2000  34.8  37.0  28.3
# 2001  26.5  51.0  22.4
# 2002  16.7  60.4  22.9
# 2003  38.8  46.9  14.3
# 2004  42.0  38.0  20.0
# 2005  41.7  39.6  18.8
# 2006  18.4  59.2  22.4
# 2007  36.0  48.0  16.0
# 2008  36.7  51.0  12.2
# 2009  40.8  42.9  16.3
# 2010  44.2  38.5  17.3
# 2011  58.3  33.3   8.3
# 2012  70.0  17.5  12.5
# 2013  51.2  31.7  17.1
# 2014  75.6  17.1   7.3
# 2015  56.4  30.8  12.8
# 2016  61.0  31.7   7.3
# 2017  75.6  12.2  12.2
# 2018  62.8  25.6  11.6
# 2019  71.4  14.3  14.3

# %%
#Bar chart of table above

colors = ["#092C5C", "#8FBCE6", "#F5D130"]

(100 * round(draft_year_school_table_pct,3)).plot(kind = "bar", color = colors, width = .7, fontsize = 12, 
edgecolor = "#092C5C", stacked = True, figsize = (16, 10.5))
plt.title("Rays Draft Picks\n by School Type", size = 28)
plt.xlabel("Year", size = 16)
plt.ylabel("School Type %", size = 16)
plt.yticks(np.arange(0, 101, step = 10))
plt.legend(["College", "High School", "Juco"], loc = "lower right", fontsize = 16)
plt.grid(color = "whitesmoke", linestyle = "-", axis = "y")
plt.savefig("Rays Draft Picks by School Type.png")
plt.show()
